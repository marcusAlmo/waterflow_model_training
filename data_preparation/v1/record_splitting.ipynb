# %% [markdown]
# ## Data Assessment of Waterflow Historical Data

# %% [markdown]
# **Metadata Summary**
# - 📅 **Date of Retrieval:** JULY 1, 2025
# - 🌐 **Source of Data:** LGU San Jacinto Treasury Records
# - 📄 **License/Permission:**
# - 🧑‍💼 **Prepared by:** MARK JUNE E. ALMOJUELA

# %% [markdown]
# This notebook is used to split the compiled records with more than one month in one file to create chunks of records for each month.

# %%
# Initialization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Split MAR_APR2020 record to create MAR2020 and APR2020

# %%
# Initialize df as None at the start
df = None

# Define the file path
file_path = os.path.normpath("../../dataset/raw/2020/MAR_APR2020.csv")

# Print the full path for verification
print(f"Attempting to load file from: {os.path.abspath(file_path)}")

try:
    if not os.path.exists(file_path):
        print("Error: File not found at the specified location.")
        dir_path = os.path.dirname(file_path)
        if not os.path.exists(dir_path):
            print(f"Error: Directory not found: {os.path.abspath(dir_path)}")
        else:
            print("Files in directory:")
            print(os.listdir(dir_path))
    else:
        # Try UTF-8 encoding first
        try:
            df = pd.read_csv(file_path)
            print("File loaded successfully with UTF-8 encoding!")
        except UnicodeDecodeError:
            print("Trying with 'latin1' encoding...")
            df = pd.read_csv(file_path, encoding='latin1')
            print("File loaded successfully with 'latin1' encoding!")
        
        # Display info if df was loaded
        if df is not None:
            print(f"\nNumber of rows: {len(df)}")
            print("\nFirst few rows:")
            print(df.head())
            print("\nColumns in the dataset:")
            print(df.columns.tolist())
            
except Exception as e:
    print(f"An error occurred: {e}")

# The df variable is now available for use in subsequent cells
# Out:
# Attempting to load file from: c:\Users\Mark June Almojuela\OneDrive - Bicol University\WaterFlow\AI\Model Training\dataset\raw\2020\MAR_APR2020.csv
# Trying with 'latin1' encoding...
# File loaded successfully with 'latin1' encoding!
#
# Number of rows: 1633
#
# First few rows:
#    Control Number      Consumer's Name       Address Water Meter Serial #  \
# 0        501549.0       Albaño, Lilane  Alicante St.                  NaN
# 1        500750.0  Aljecera, Marcelino  Alicante St.                  NaN
# 2        500990.0       Almiñana, Irus  Alicante St.                  NaN
# 3        500505.0       Almiñe, Edison  Alicante St.             95022096
# 4        501542.0       Almiñe, Filben  Alicante St.                  NaN
#
#   Previous Present  Cons.    Amount
# 0      218     247   29.0    87.00
# 1     3030    3051   21.0    63.00
# 2      471     537   66.0   198.00
# 3        2      63   61.0   183.00
# 4     3271    3314   43.0   129.00
#
# Columns in the dataset:
# ['Control Number', "Consumer's Name", 'Address', 'Water Meter Serial #', 'Previous', 'Present', 'Cons.', 'Amount']

# %%
# Count of null/NaN values in each column
null_counts = df.isnull().sum()
print("Count of null/NaN values per column:")
print(null_counts[null_counts > 0])  # Only show columns with null values

# Count of rows with any null/NaN values
rows_with_nulls = df[df.isnull().any(axis=1)]
print(f"\nNumber of rows with any null/NaN values: {len(rows_with_nulls)}")
# Out:
# Count of null/NaN values per column:
# Control Number            1
# Water Meter Serial #    698
# Previous                201
# Present                 403
# Cons.                   548
# Amount                  416
# dtype: int64
#
# Number of rows with any null/NaN values: 1026

# %% [markdown]
# Creating MAR2020 AND APR2020 records

# %%
# Logic test for MAR_APR2020.csv record split
for index, row in df.iterrows():
    try:
        control_number = row["Control Number"]
        consumer_name = row["Consumer's Name"]
        address = row["Address"]
        serial_number = row["Water Meter Serial #"]
        try:
            previous_reading = int(row["Previous"])
        except ValueError:
            previous_reading = 0
        
        try:
            present_reading = int(row["Present"])
        except ValueError:
            if previous_reading > 0:
                present_reading = previous_reading
            else:
                present_reading = 0
        
        current_reading = present_reading - ((present_reading - previous_reading) / 2)
        
        total_consumption = present_reading - previous_reading
        total_amount = total_consumption * 10

        print(control_number, consumer_name, address, serial_number, 
              previous_reading, current_reading, total_consumption, total_amount)
              
    except Exception as e:
        print(f"Error processing row {index}: {e}")
# Out:
# 501549.0 Albaño, Lilane Alicante St. nan 218 232.5 29 290
# 500750.0 Aljecera, Marcelino Alicante St. nan 3030 3040.5 21 210
# 500990.0 Almiñana, Irus Alicante St. nan 471 504.0 66 660
# 500505.0 Almiñe, Edison Alicante St. 95022096 2 32.5 61 610
# 501542.0 Almiñe, Filben Alicante St. nan 3271 3292.5 43 430
# 500431.0 Almiñe, Franchie Alicante St. 121006093 0 0.0 0 0
# 500263.0 Almodal, Arna Alicante St. 9588526 5228 5240.5 25 250
# 501240.0 Almocera, Owen Alicante St. nan 67 102.5 71 710
# 500484.0 Almodal, Erlinda Alicante St. 028086-02 0 0.0 0 0
# 500739.0 Almodal, Jolly Alicante St. 017902-02 1795 1861.5 133 1330
# 500544.0 Almodal, Noe Alicante St. nan 2418 2418.0 0 0
# 500187.0 Almodiel, Arles Alicante St. 9074313 3210 3210.0 0 0
# 501447.0 Almodiel, Mary Grace Alicante St. nan 238 240.5 5 50
# 501453.0 Alcantara, Hilda Alicante St. nan 183 189.5 13 130
# 501317.0 Almoete, Ike Alicante St. nan 595 603.0 16 160
# 501280.0 Almojuela, Arlic Alicante St. nan 424 448.0 48 480
# 500248.0 Almojuela, Rogelio Alicante St. 956320 6706 6745.0 78 780
# 501028.0 Almoradie, Marites Alicante St. nan 1914 1923.5 19 190
# 501437.0 Almoradie, Geann Alicante St. nan 1386 1437.0 102 1020
# 500433.0 Almoradie, Marina Alicante St. nan 340 369.0 58 580
# 500260.0 Altiche, Antonio Alicante St. nan 0 0.0 0 0
# 501663.0 Altiche, Nenita Alicante St. nan 56 56.0 0 0
# 500185.0 Aspa, Leny Alicante St. 245534 1518 1522.5 9 90
# 500169.0 Añonuevo, Paz Alicante St. 027568-02 3162 3162.0 0 0
# 501232.0 Anabe, Antonio Alicante St. 08-82569 0 0.0 0 0
# 500479.0 Azares, Jeffrey Alicante St. 028462-02 64 82.5 37 370
# 500009.0 Barruga, Expedito Alicante St. 017766-02 2014 2023.5 19 190
# 500472.0 Barruga, Loreto Alicante St. 028652-02 814 849.0 70 700
# 501393.0 Barrun, Ana Alicante St. 028576-02 602 623.0 42 420
# 500094.0 Barrun, Divina Alicante St. 954950 2703 2722.0 38 380
# 501020.0 Barrun, Emilio Alicante St. nan 1995 2012.5 35 350
# 501033.0 Amor, Candelaria Esparrago St. 017887-02 1125 1157.0 64 640
# 501348.0 Arcenas, Francis Esparrago St. 1737802 0 0.0 0 0
# 501398.0 Arcenas, Francis 2 Esparrago St. 028572-02 0 0.0 0 0
# 501278.0 Bagobe, Fausto Ceasar Esparrago St. 024237-02 397 399.0 4 40
# 500003.0 Bagobe, Penelope Esparrago St. 968893 4028 4046.0 36 360
# 501042.0 Barrun, Marlon Esparrago St. nan 2684 2705.5 43 430
# 500321.0 Barrun, May Esparrago St. 028249-02 5241 5258.5 35 350
# 500434.0 Barrun, Ranulfo Esparrago St. 95032548 4559 4573.0 28 280
# 501188.0 Bartolata, Ariel Esparrago St. 100883 0 0.0 0 0
# 500503.0 Bartolata, Ariosto Esparrago St. 9667670 4127 4159.0 64 640
# 500929.0 Bartolata, Ben Esparrago St. 07-092317 0 0.0 0 0
# 501691.0 Bartolata, Judith Esparrago St. nan 24 50.0 52 520
# 500005.0 Bartolata, Ruel Esparrago St. 028347-02 3378 3378.0 0 0
# 500508.0 Bartolata, Vivian Esparrago St. 82871 1068 1108.0 80 800
# 501134.0 Bartolay, Michael Esparrago St. 10036730 23 36.5 27 270
# 500266.0 Bayrante, Menie Esparrago St. 807851 6806 6819.5 27 270
# 500007.0 Cabiles, Nita Esparrago St. 028192-02 1130 1143.0 26 260
# 500643.0 Cantoria, Nena Esparrago St. 017922-02 3992 4038.0 92 920
# 500235.0 Carpio, Neil Esparrago St. 029109-02 740 757.5 35 350
# 500624.0 Casilao, Cesar Esparrago St. 9244430 78 78.0 0 0
# 500004.0 Cerillo, Lea Esparrago St. 95031646 3507 3527.0 40 400
# 500323.0 Cervantes, Alita Esparrago St. 151844 1141 1158.5 35 350
# 500261.0 Constantino, Rogelio Esparrago St. 028197-02 0 0.0 0 0
# 500613.0 Dejucos, Joel Esparrago St. 43281 4704 4725.0 42 420
# 500006.0 Dejucos, Mercy Esparrago St. nan 0 0.0 0 0
# 500086.0 Dejumo, Milagros Esparrago St. 119057 317 318.0 2 20
# 500449.0 Delavin, Natividad Esparrago St. 2983 835 871.5 73 730
# 500325.0 Delos Santos, Teddy Esparrago St. 952463 5465 5486.5 43 430
# 500987.0 Don, Maribel Esparrago St. nan 0 0.0 0 0
# 500001.0 Encinares, Roberto Esparrago St. 249682 0 0.0 0 0
# 501552.0 Escorel, Cerconsecion Esparrago St. nan 113 119.5 13 130
# 500886.0 Espares, Julieta Esparrago St. 0276322-0 1512 1512.0 0 0
# 501480.0 Espares, Jennefer Esparrago St. 027459-02 399 419.5 41 410
# 501452.0 Español, Corazon Esparrago St. nan 814 831.5 35 350
# ...
# 500236.0 Constantino, Adolfo Letada St. 957992 1823 1832.0 18 180
# 500477.0 Constantino, Aida Letada St. 70013 0 0.0 0 0
# 500242.0 Delavin, Edwin Letada St. 9867307 3161 3189.0 56 560
# 501521.0 Delavin, Delmor Letada St. nan 388 401.5 27 270
# 500176.0 Espenilla, Amador Letada St. 028297-02 681 829.5 297 2970
# 500226.0 Almoete, Ligaya Villamor St. 95761 2194 2200.0 12 120
# 500885.0 Añonuevo, Florante Villamor St. nan 0 0.0 0 0
# 500640.0 Añonuevo, Lilibeth Villamor St. 9867182 2458 2466.0 16 160
# 501186.0 Balingasa, Adril (1) Villamor St. 10114216 447 487.5 81 810
# 501215.0 Balingasa, Ma. Elena (3) Villamor St. 901847 162 182.5 41 410
# 501228.0 Balingasa, Joadel (2) Villamor St. 10114293 676 676.0 0 0
# 501217.0 Balingasa, Jea (4) Villamor St. 10113695 453 475.0 44 440
# 501257.0 Barrun, Ma. Jossette Villamor St. nan 2721 2761.5 81 810
# 500090.0 Barrun, Emma Villamor St. 957419 1782 1816.5 69 690
# 501634.0 Benamera, Sharon Mae Villamor St. nan 548 657.0 218 2180
# 501523.0 Diano, Alvin Villamor St. nan 522 568.0 92 920
# 500642.0 Escorel, Elisa Villamor St. nan 3522 3548.0 52 520
# 501112.0 Espiloy, Nemia Villamor St. 151912 251 297.5 93 930
# 500092.0 Bartolata, Eduardo Villamor St. 967426 0 0.0 0 0
# 501012.0 Garibalde, Alcantara Villamor St. nan 0 0.0 0 0
# 500919.0 Granado, Nida Villamor St. 10758 0 0.0 0 0
# 501110.0 Gutierrez, Elmo Villamor St. 2624 10 10.0 0 0
# 501662.0 Latagan, Mercy Villamor St. nan 0 21.5 43 430
# 501111.0 Laurio, Serenida Villamor St. 017890-02 1339 1390.0 102 1020
# 500641.0 Moya, Conception Villamor St. 017921-02 0 0.0 0 0
# 500021.0 Nacino, Christopher Villamor St. 9511454 1784 1785.5 3 30
# 500091.0 Ragasa, Fe Villamor St. 017732-02 2894 2916.0 44 440
# 501109.0 Almocera, Ricky Puro, Calipat-an 18010 0 0.0 0 0
# 501381.0 Gaurano, Clutario Puro, Calipat-an nan 0 0.0 0 0

# %%
import csv

# Create the output directory if it doesn't exist
mar_output_dir = os.path.dirname("../../dataset/raw/2020/MAR2020.csv")
apr_output_dir = os.path.dirname("../../dataset/raw/2020/APR2020.csv")
os.makedirs(mar_output_dir, exist_ok=True)
os.makedirs(apr_output_dir, exist_ok=True)

with open("../../dataset/raw/2020/MAR2020.csv", "w", newline="", encoding='latin-1') as mar_file \
    , open("../../dataset/raw/2020/APR2020.csv", "w", newline="", encoding='latin-1') as apr_file:
    mar_csv_writer = csv.writer(mar_file)
    apr_csv_writer = csv.writer(apr_file)
    # Write header
    mar_csv_writer.writerow([
        "Control Number", "Consumer's Name", "Address", 
        "Water Meter Serial #", "Previous", "Present", 
        "Cons.", "Amount", "Connection Status"
    ])
    apr_csv_writer.writerow([
        "Control Number", "Consumer's Name", "Address", 
        "Water Meter Serial #", "Previous", "Present", 
        "Cons.", "Amount", "Connection Status"
    ])

    for index, row in df.iterrows():
        try:
            control_number = row["Control Number"]
            consumer_name = row["Consumer's Name"]
            address = row["Address"]
            serial_number = row["Water Meter Serial #"]
            connection_status = None
            
            # Handle Previous Reading
            try:
                mar_previous_reading = int(float(str(row["Previous"]).strip()))
                connection_status = "Connected"
            except (ValueError, TypeError):
                if row['Previous'] is not None:
                    prev_status = str(row['Previous']).strip().upper() if pd.notna(row['Previous']) else ""
                    if prev_status in ["DISC", "DISC."]:
                        connection_status = "Disconnected"
                    elif prev_status:   
                        connection_status = prev_status.capitalize()
                else:
                    mar_previous_reading = 0
                    connection_status = "Unknown"
            
            # Handle Present Reading
            try:
                mar_present_reading = int(float(str(row["Present"]).strip()))
                connection_status = "Connected" if connection_status is None else connection_status
            except (ValueError, TypeError):
                mar_present_reading = mar_previous_reading if mar_previous_reading is not None else 0
                connection_status = "Unknown" if connection_status is None else connection_status
            
            # Calculate values for March
            mar_current_reading = mar_previous_reading + round((mar_present_reading - mar_previous_reading) / 2)
            mar_total_consumption = mar_current_reading - mar_previous_reading
            mar_total_amount = mar_total_consumption * 10 

            new_record_mar = [
                control_number, consumer_name, address, serial_number,
                mar_previous_reading, round(mar_current_reading),
                mar_total_consumption, mar_total_amount, connection_status
            ]

            # Calculate values April
            apr_previous_reading = mar_current_reading
            
            # Handle Present Reading
            try:
                apr_current_reading = int(float(str(row["Present"]).strip()))
            except (ValueError, TypeError):
                apr_current_reading = apr_previous_reading if apr_previous_reading is not None else 0
            
            # Calculate values for April
            apr_total_consumption = apr_current_reading - apr_previous_reading
            apr_total_amount = apr_total_consumption * 10 

            new_record_apr = [
                control_number, consumer_name, address, serial_number,
                apr_previous_reading, round(apr_current_reading),
                apr_total_consumption, apr_total_amount, connection_status
            ]            
            # Print Record
            print(f"Processed MAR {index} rows: {new_record_mar}")
            print(f"Processed APR {index} rows: {new_record_apr}")
            
            # Write row
            mar_csv_writer.writerow(new_record_mar)
            apr_csv_writer.writerow(new_record_apr) 

            # Reset connection status
            connection_status = None
               
        except Exception as e:
            print(f"Error processing row {index}: {e}")
            continue

print("Processing complete!")
# Out:
# Processed MAR 0 rows: [501549.0, 'Albaño, Lilane', 'Alicante St.', nan, 218, 232, 14, 140, 'Connected']
# Processed APR 0 rows: [501549.0, 'Albaño, Lilane', 'Alicante St.', nan, 232, 247, 15, 150, 'Connected']
# Processed MAR 1 rows: [500750.0, 'Aljecera, Marcelino', 'Alicante St.', nan, 3030, 3040, 10, 100, 'Connected']
# Processed APR 1 rows: [500750.0, 'Aljecera, Marcelino', 'Alicante St.', nan, 3040, 3051, 11, 110, 'Connected']
# Processed MAR 2 rows: [500990.0, 'Almiñana, Irus', 'Alicante St.', nan, 471, 504, 33, 330, 'Connected']
# Processed APR 2 rows: [500990.0, 'Almiñana, Irus', 'Alicante St.', nan, 504, 537, 33, 330, 'Connected']
# Processed MAR 3 rows: [500505.0, 'Almiñe, Edison', 'Alicante St.', '95022096', 2, 32, 30, 300, 'Connected']
# Processed APR 3 rows: [500505.0, 'Almiñe, Edison', 'Alicante St.', '95022096', 32, 63, 31, 310, 'Connected']
# Processed MAR 4 rows: [501542.0, 'Almiñe, Filben', 'Alicante St.', nan, 3271, 3293, 22, 220, 'Connected']
# Processed APR 4 rows: [501542.0, 'Almiñe, Filben', 'Alicante St.', nan, 3293, 3314, 21, 210, 'Connected']
# Processed MAR 5 rows: [500431.0, 'Almiñe, Franchie', 'Alicante St.', '121006093', 3271, 3271, 0, 0, 'Disconnected']
# Processed APR 5 rows: [500431.0, 'Almiñe, Franchie', 'Alicante St.', '121006093', 3271, 3271, 0, 0, 'Disconnected']
# Processed MAR 6 rows: [500263.0, 'Almodal, Arna', 'Alicante St.', '9588526', 5228, 5240, 12, 120, 'Connected']
# Processed APR 6 rows: [500263.0, 'Almodal, Arna', 'Alicante St.', '9588526', 5240, 5253, 13, 130, 'Connected']
# Processed MAR 7 rows: [501240.0, 'Almocera, Owen', 'Alicante St.', nan, 67, 103, 36, 360, 'Connected']
# Processed APR 7 rows: [501240.0, 'Almocera, Owen', 'Alicante St.', nan, 103, 138, 35, 350, 'Connected']
# Processed MAR 8 rows: [500484.0, 'Almodal, Erlinda', 'Alicante St.', '028086-02', 67, 67, 0, 0, 'Unknown']
# Processed APR 8 rows: [500484.0, 'Almodal, Erlinda', 'Alicante St.', '028086-02', 67, 67, 0, 0, 'Unknown']
# Processed MAR 9 rows: [500739.0, 'Almodal, Jolly', 'Alicante St.', '017902-02', 1795, 1861, 66, 660, 'Connected']
# Processed APR 9 rows: [500739.0, 'Almodal, Jolly', 'Alicante St.', '017902-02', 1861, 1928, 67, 670, 'Connected']
# Processed MAR 10 rows: [500544.0, 'Almodal, Noe', 'Alicante St.', nan, 2418, 2418, 0, 0, 'Connected']
# Processed APR 10 rows: [500544.0, 'Almodal, Noe', 'Alicante St.', nan, 2418, 2418, 0, 0, 'Connected']
# Processed MAR 11 rows: [500187.0, 'Almodiel, Arles', 'Alicante St.', '9074313', 3210, 3210, 0, 0, 'Connected']
# Processed APR 11 rows: [500187.0, 'Almodiel, Arles', 'Alicante St.', '9074313', 3210, 3210, 0, 0, 'Connected']
# Processed MAR 12 rows: [501447.0, 'Almodiel, Mary Grace', 'Alicante St.', nan, 238, 240, 2, 20, 'Connected']
# Processed APR 12 rows: [501447.0, 'Almodiel, Mary Grace', 'Alicante St.', nan, 240, 243, 3, 30, 'Connected']
# Processed MAR 13 rows: [501453.0, 'Alcantara, Hilda', 'Alicante St.', nan, 183, 189, 6, 60, 'Connected']
# Processed APR 13 rows: [501453.0, 'Alcantara, Hilda', 'Alicante St.', nan, 189, 196, 7, 70, 'Connected']
# Processed MAR 14 rows: [501317.0, 'Almoete, Ike', 'Alicante St.', nan, 595, 603, 8, 80, 'Connected']
# Processed APR 14 rows: [501317.0, 'Almoete, Ike', 'Alicante St.', nan, 603, 611, 8, 80, 'Connected']
# Processed MAR 15 rows: [501280.0, 'Almojuela, Arlic', 'Alicante St.', nan, 424, 448, 24, 240, 'Connected']
# Processed APR 15 rows: [501280.0, 'Almojuela, Arlic', 'Alicante St.', nan, 448, 472, 24, 240, 'Connected']
# Processed MAR 16 rows: [500248.0, 'Almojuela, Rogelio', 'Alicante St.', '956320', 6706, 6745, 39, 390, 'Connected']
# Processed APR 16 rows: [500248.0, 'Almojuela, Rogelio', 'Alicante St.', '956320', 6745, 6784, 39, 390, 'Connected']
# Processed MAR 17 rows: [501028.0, 'Almoradie, Marites', 'Alicante St.', nan, 1914, 1924, 10, 100, 'Connected']
# Processed APR 17 rows: [501028.0, 'Almoradie, Marites', 'Alicante St.', nan, 1924, 1933, 9, 90, 'Connected']
# Processed MAR 18 rows: [501437.0, 'Almoradie, Geann', 'Alicante St.', nan, 1386, 1437, 51, 510, 'Connected']
# Processed APR 18 rows: [501437.0, 'Almoradie, Geann', 'Alicante St.', nan, 1437, 1488, 51, 510, 'Connected']
# Processed MAR 19 rows: [500433.0, 'Almoradie, Marina', 'Alicante St.', nan, 340, 369, 29, 290, 'Connected']
# Processed APR 19 rows: [500433.0, 'Almoradie, Marina', 'Alicante St.', nan, 369, 398, 29, 290, 'Connected']
# Processed MAR 20 rows: [500260.0, 'Altiche, Antonio', 'Alicante St.', nan, 340, 340, 0, 0, 'Unknown']
# Processed APR 20 rows: [500260.0, 'Altiche, Antonio', 'Alicante St.', nan, 340, 340, 0, 0, 'Unknown']
# Processed MAR 21 rows: [501663.0, 'Altiche, Nenita', 'Alicante St.', nan, 56, 56, 0, 0, 'Connected']
# Processed APR 21 rows: [501663.0, 'Altiche, Nenita', 'Alicante St.', nan, 56, 56, 0, 0, 'Connected']
# Processed MAR 22 rows: [500185.0, 'Aspa, Leny', 'Alicante St.', '245534', 1518, 1522, 4, 40, 'Connected']
# Processed APR 22 rows: [500185.0, 'Aspa, Leny', 'Alicante St.', '245534', 1522, 1527, 5, 50, 'Connected']
# Processed MAR 23 rows: [500169.0, 'Añonuevo, Paz', 'Alicante St.', '027568-02', 3162, 3162, 0, 0, 'Connected']
# Processed APR 23 rows: [500169.0, 'Añonuevo, Paz', 'Alicante St.', '027568-02', 3162, 3162, 0, 0, 'Connected']
# Processed MAR 24 rows: [501232.0, 'Anabe, Antonio', 'Alicante St.', '08-82569', 3162, 3162, 0, 0, 'Defect']
# Processed APR 24 rows: [501232.0, 'Anabe, Antonio', 'Alicante St.', '08-82569', 3162, 3162, 0, 0, 'Defect']
# Processed MAR 25 rows: [500479.0, 'Azares, Jeffrey', 'Alicante St.', '028462-02', 64, 82, 18, 180, 'Connected']
# Processed APR 25 rows: [500479.0, 'Azares, Jeffrey', 'Alicante St.', '028462-02', 82, 101, 19, 190, 'Connected']
# Processed MAR 26 rows: [500009.0, 'Barruga, Expedito', 'Alicante St.', '017766-02', 2014, 2024, 10, 100, 'Connected']
# Processed APR 26 rows: [500009.0, 'Barruga, Expedito', 'Alicante St.', '017766-02', 2024, 2033, 9, 90, 'Connected']
# Processed MAR 27 rows: [500472.0, 'Barruga, Loreto', 'Alicante St.', '028652-02', 814, 849, 35, 350, 'Connected']
# Processed APR 27 rows: [500472.0, 'Barruga, Loreto', 'Alicante St.', '028652-02', 849, 884, 35, 350, 'Connected']
# Processed MAR 28 rows: [501393.0, 'Barrun, Ana', 'Alicante St.', '028576-02', 602, 623, 21, 210, 'Connected']
# Processed APR 28 rows: [501393.0, 'Barrun, Ana', 'Alicante St.', '028576-02', 623, 644, 21, 210, 'Connected']
# Processed MAR 29 rows: [500094.0, 'Barrun, Divina', 'Alicante St.', '954950', 2703, 2722, 19, 190, 'Connected']
# Processed APR 29 rows: [500094.0, 'Barrun, Divina', 'Alicante St.', '954950', 2722, 2741, 19, 190, 'Connected']
# Processed MAR 30 rows: [501020.0, 'Barrun, Emilio', 'Alicante St.', nan, 1995, 2013, 18, 180, 'Connected']
# Processed APR 30 rows: [501020.0, 'Barrun, Emilio', 'Alicante St.', nan, 2013, 2030, 17, 170, 'Connected']
# Processed MAR 31 rows: [500692.0, 'Barrun, Jose', 'Alicante St.', nan, 1995, 1995, 0, 0, 'Unknown']
# Processed APR 31 rows: [500692.0, 'Barrun, Jose', 'Alicante St.', nan, 1995, 1995, 0, 0, 'Unknown']
# Processed MAR 32 rows: [500585.0, 'Barrun, Nida', 'Alicante St.', nan, 321, 347, 26, 260, 'Connected']
# Processed APR 32 rows: [500585.0, 'Barrun, Nida', 'Alicante St.', nan, 347, 372, 25, 250, 'Connected']
# Processed MAR 33 rows: [500330.0, 'Barrun, Vito', 'Alicante St.', '151228', 321, 177, -144, -1440, 'Connected']
# Processed APR 33 rows: [500330.0, 'Barrun, Vito', 'Alicante St.', '151228', 177, 32, -145, -1450, 'Connected']
# Processed MAR 34 rows: [501260.0, 'Barsaga, Natividad', 'Alicante St.', '11075846', 130, 172, 42, 420, 'Connected']
# Processed APR 34 rows: [501260.0, 'Barsaga, Natividad', 'Alicante St.', '11075846', 172, 214, 42, 420, 'Connected']
# Processed MAR 35 rows: [501330.0, 'Barsaga, Natividad 2', 'Alicante St.', nan, 66, 66, 0, 0, 'Connected']
# Processed APR 35 rows: [501330.0, 'Barsaga, Natividad 2', 'Alicante St.', nan, 66, 66, 0, 0, 'Connected']
# Processed MAR 36 rows: [501167.0, 'Bartolabac, Renato', 'Alicante St.', nan, 1273, 1287, 14, 140, 'Connected']
# Processed APR 36 rows: [501167.0, 'Bartolabac, Renato', 'Alicante St.', nan, 1287, 1302, 15, 150, 'Connected']
# Processed MAR 37 rows: [500740.0, 'Bartolata, Jose', 'Alicante St.', '017903-02', 1273, 1273, 0, 0, 'Unknown']
# Processed APR 37 rows: [500740.0, 'Bartolata, Jose', 'Alicante St.', '017903-02', 1273, 1273, 0, 0, 'Unknown']
# Processed MAR 38 rows: [500278.0, 'Bartolay, Felipe', 'Alicante St.', '028463-02', 1878, 1892, 14, 140, 'Connected']
# Processed APR 38 rows: [500278.0, 'Bartolay, Felipe', 'Alicante St.', '028463-02', 1892, 1905, 13, 130, 'Connected']
# Processed MAR 39 rows: [500861.0, 'Bartolata, Lourdes', 'Alicante St.', '957925', 2189, 2201, 12, 120, 'Connected']
# Processed APR 39 rows: [500861.0, 'Bartolata, Lourdes', 'Alicante St.', '957925', 2201, 2214, 13, 130, 'Connected']
# Processed MAR 40 rows: [501021.0, 'Bartolay, Isaias', 'Alicante St.', nan, 2189, 2189, 0, 0, 'Unknown']
# Processed APR 40 rows: [501021.0, 'Bartolay, Isaias', 'Alicante St.', nan, 2189, 2189, 0, 0, 'Unknown']
# Processed MAR 41 rows: [500254.0, 'Bartolay, Nilda', 'Alicante St.', '028194-02', 1804, 1805, 1, 10, 'Connected']
# Processed APR 41 rows: [500254.0, 'Bartolay, Nilda', 'Alicante St.', '028194-02', 1805, 1806, 1, 10, 'Connected']
# Processed MAR 42 rows: [501301.0, 'Bartolay, Nilo', 'Alicante St.', nan, 910, 920, 10, 100, 'Connected']
# Processed APR 42 rows: [501301.0, 'Bartolay, Nilo', 'Alicante St.', nan, 920, 931, 11, 110, 'Connected']
# Processed MAR 43 rows: [501048.0, 'Bartolay, Nolyn', 'Alicante St.', nan, 496, 532, 36, 360, 'Connected']
# Processed APR 43 rows: [501048.0, 'Bartolay, Nolyn', 'Alicante St.', nan, 532, 567, 35, 350, 'Connected']
# Processed MAR 44 rows: [500095.0, 'Bartolay, Rustom', 'Alicante St.', '9521569', 1322, 1332, 10, 100, 'Connected']
# Processed APR 44 rows: [500095.0, 'Bartolay, Rustom', 'Alicante St.', '9521569', 1332, 1342, 10, 100, 'Connected']
# Processed MAR 45 rows: [501176.0, 'Bartolay, Marites', 'Alicante St.', '10092103', 1322, 1519, 197, 1970, 'Defect']
# Processed APR 45 rows: [501176.0, 'Bartolay, Marites', 'Alicante St.', '10092103', 1519, 1716, 197, 1970, 'Defect']
# Processed MAR 46 rows: [500045.0, 'Bartolay, Orlando', 'Alicante St.', nan, 1322, 1322, 0, 0, 'Disconnected']
# Processed APR 46 rows: [500045.0, 'Bartolay, Orlando', 'Alicante St.', nan, 1322, 1322, 0, 0, 'Disconnected']
# Processed MAR 47 rows: [500405.0, 'Bartolay, Orlando', 'Alicante St.', nan, 1571, 1578, 7, 70, 'Connected']
# Processed APR 47 rows: [500405.0, 'Bartolay, Orlando', 'Alicante St.', nan, 1578, 1585, 7, 70, 'Connected']
# Processed MAR 48 rows: [500380.0, 'Borejon, Melchor', 'Alicante St.', '20048213', 1064, 1071, 7, 70, 'Connected']
# Processed APR 48 rows: [500380.0, 'Borejon, Melchor', 'Alicante St.', '20048213', 1071, 1078, 7, 70, 'Connected']
# Processed MAR 49 rows: [501329.0, 'Borejon, Noli', 'Alicante St.', nan, 238, 256, 18, 180, 'Connected']
# Processed APR 49 rows: [501329.0, 'Borejon, Noli', 'Alicante St.', nan, 256, 275, 19, 190, 'Connected']
# Processed MAR 50 rows: [500377.0, 'Borromeo, Elisa', 'Alicante St.', '9665024', 234, 247, 13, 130, 'Connected']
# Processed APR 50 rows: [500377.0, 'Borromeo, Elisa', 'Alicante St.', '9665024', 247, 260, 13, 130, 'Connected']
# Processed MAR 51 rows: [501522.0, 'Borromeo, Gener', 'Alicante St.', nan, 166, 174, 8, 80, 'Connected']
# Processed APR 51 rows: [501522.0, 'Borromeo, Gener', 'Alicante St.', nan, 174, 182, 8, 80, 'Connected']
# Processed MAR 52 rows: [500251.0, 'Cabiles, Nicanor', 'Alicante St.', '970701083', 904, 942, 38, 380, 'Connected']
# Processed APR 52 rows: [500251.0, 'Cabiles, Nicanor', 'Alicante St.', '970701083', 942, 980, 38, 380, 'Connected']
# Processed MAR 53 rows: [500014.0, 'Canchela, Emma', 'Alicante St.', '954415', 3713, 3725, 12, 120, 'Connected']
# Processed APR 53 rows: [500014.0, 'Canchela, Emma', 'Alicante St.', '954415', 3725, 3738, 13, 130, 'Connected']
# Processed MAR 54 rows: [500262.0, 'Canchela, Isaias', 'Alicante St.', '952564', 2700, 2713, 13, 130, 'Connected']
# Processed APR 54 rows: [500262.0, 'Canchela, Isaias', 'Alicante St.', '952564', 2713, 2726, 13, 130, 'Connected']
# Processed MAR 55 rows: [501676.0, 'Cantoria, Jose', 'Alicante St.', nan, 18, 30, 12, 120, 'Connected']
# Processed APR 55 rows: [501676.0, 'Cantoria, Jose', 'Alicante St.', nan, 30, 43, 13, 130, 'Connected']
# Processed MAR 56 rows: [500696.0, 'Cantoria, Lourdes', 'Alicante St.', '951475', 303, 351, 48, 480, 'Connected']
# Processed APR 56 rows: [500696.0, 'Cantoria, Lourdes', 'Alicante St.', '951475', 351, 399, 48, 480, 'Connected']
# Processed MAR 57 rows: [500015.0, 'Cantuba, Fe', 'Alicante St.', '017010-02', 1505, 1515, 10, 100, 'Connected']
# Processed APR 57 rows: [500015.0, 'Cantuba, Fe', 'Alicante St.', '017010-02', 1515, 1524, 9, 90, 'Connected']
# Processed MAR 58 rows: [500249.0, 'Constantino, Marivic', 'Alicante St.', '028469-02', 1745, 1751, 6, 60, 'Connected']
# Processed APR 58 rows: [500249.0, 'Constantino, Marivic', 'Alicante St.', '028469-02', 1751, 1756, 5, 50, 'Connected']
# Processed MAR 59 rows: [501129.0, 'Constantino, Pascual', 'Alicante St.', nan, 372, 387, 15, 150, 'Connected']
# Processed APR 59 rows: [501129.0, 'Constantino, Pascual', 'Alicante St.', nan, 387, 402, 15, 150, 'Connected']
# Processed MAR 60 rows: [500012.0, 'Dejucos, Lony', 'Alicante St.', '958902', 372, 372, 0, 0, 'Unknown']
# Processed APR 60 rows: [500012.0, 'Dejucos, Lony', 'Alicante St.', '958902', 372, 372, 0, 0, 'Unknown']
# Processed MAR 61 rows: [501411.0, 'Dein, Sharon', 'Alicante St.', nan, 32, 32, 0, 0, 'Connected']
# Processed APR 61 rows: [501411.0, 'Dein, Sharon', 'Alicante St.', nan, 32, 32, 0, 0, 'Connected']
# Processed MAR 62 rows: [500523.0, 'Dejumo, Jenalyn', 'Alicante St.', '017144-02', 32, 32, 0, 0, 'Unknown']
# Processed APR 62 rows: [500523.0, 'Dejumo, Jenalyn', 'Alicante St.', '017144-02', 32, 32, 0, 0, 'Unknown']
# Processed MAR 63 rows: [501024.0, 'Dejumo, Sergia', 'Alicante St.', nan, 32, 32, 0, 0, 'Unknown']
# Processed APR 63 rows: [501024.0, 'Dejumo, Sergia', 'Alicante St.', nan, 32, 32, 0, 0, 'Unknown']
# Processed MAR 64 rows: [500316.0, 'Delariarte, Nicanor', 'Alicante St.', '027451-02', 3645, 3665, 20, 200, 'Connected']
# Processed APR 64 rows: [500316.0, 'Delariarte, Nicanor', 'Alicante St.', '027451-02', 3665, 3685, 20, 200, 'Connected']
# Processed MAR 65 rows: [500357.0, 'Elloso, Amy', 'Alicante St.', nan, 3645, 3645, 0, 0, 'Unknown']
# Processed APR 65 rows: [500357.0, 'Elloso, Amy', 'Alicante St.', nan, 3645, 3645, 0, 0, 'Unknown']
# Processed MAR 66 rows: [501105.0, 'Elloso, Amy/Card Bank', 'Alicante St.', '6V1997', 239, 253, 14, 140, 'Connected']
# Processed APR 66 rows: [501105.0, 'Elloso, Amy/Card Bank', 'Alicante St.', '6V1997', 253, 266, 13, 130, 'Connected']
# Processed MAR 67 rows: [500985.0, 'Escorel, Potito', 'Alicante St.', '17881', 861, 862, 1, 10, 'Connected']
# Processed APR 67 rows: [500985.0, 'Escorel, Potito', 'Alicante St.', '17881', 862, 863, 1, 10, 'Connected']
# Processed MAR 68 rows: [501022.0, 'Español, Ave', 'Alicante St.', '70412', 31, 31, 0, 0, 'Connected']
# Processed APR 68 rows: [501022.0, 'Español, Ave', 'Alicante St.', '70412', 31, 32, 1, 10, 'Connected']
# Processed MAR 69 rows: [501379.0, 'Esparrago, Eden', 'Alicante St.', nan, 367, 369, 2, 20, 'Connected']
# Processed APR 69 rows: [501379.0, 'Esparrago, Eden', 'Alicante St.', nan, 369, 371, 2, 20, 'Connected']
# Processed MAR 70 rows: [500340.0, 'Espares, Junard', 'Alicante St.', nan, 3152, 3224, 72, 720, 'Connected']
# Processed APR 70 rows: [500340.0, 'Espares, Junard', 'Alicante St.', nan, 3224, 3296, 72, 720, 'Connected']
# Processed MAR 71 rows: [500552.0, 'Espenida, Nita', 'Alicante St.', '027564-02', 3389, 3409, 20, 200, 'Connected']
# Processed APR 71 rows: [500552.0, 'Espenida, Nita', 'Alicante St.', '027564-02', 3409, 3428, 19, 190, 'Connected']
# Processed MAR 72 rows: [500264.0, 'Espenilla, Rosito', 'Alicante St.', '89300', 1708, 1745, 37, 370, 'Connected']
# Processed APR 72 rows: [500264.0, 'Espenilla, Rosito', 'Alicante St.', '89300', 1745, 1782, 37, 370, 'Connected']
# Processed MAR 73 rows: [500905.0, 'Espenilla, Rosito (B)', 'Alicante St.', nan, 2502, 2521, 19, 190, 'Connected']
# Processed APR 73 rows: [500905.0, 'Espenilla, Rosito (B)', 'Alicante St.', nan, 2521, 2540, 19, 190, 'Connected']
# Processed MAR 74 rows: [500146.0, 'Espinosa, Carlos', 'Alicante St.', '957520', 5598, 5623, 25, 250, 'Connected']
# Processed APR 74 rows: [500146.0, 'Espinosa, Carlos', 'Alicante St.', '957520', 5623, 5648, 25, 250, 'Connected']
# Processed MAR 75 rows: [500563.0, 'Espinosa, Emily', 'Alicante St.', '017798-02', 2526, 2530, 4, 40, 'Connected']
# Processed APR 75 rows: [500563.0, 'Espinosa, Emily', 'Alicante St.', '017798-02', 2530, 2535, 5, 50, 'Connected']
# Processed MAR 76 rows: [500781.0, 'Flores, Berwin', 'Alicante St.', nan, 2025, 2025, 0, 0, 'Connected']
# Processed APR 76 rows: [500781.0, 'Flores, Berwin', 'Alicante St.', nan, 2025, 2025, 0, 0, 'Connected']
# Processed MAR 77 rows: [501316.0, 'Flores, Christian', 'Alicante St.', nan, 48, 48, 0, 0, 'Connected']
# Processed APR 77 rows: [501316.0, 'Flores, Christian', 'Alicante St.', nan, 48, 48, 0, 0, 'Connected']
# Processed MAR 78 rows: [500564.0, 'Flores, Danilo', 'Alicante St.', '86907', 48, 48, 0, 0, 'Unknown']
# Processed APR 78 rows: [500564.0, 'Flores, Danilo', 'Alicante St.', '86907', 48, 48, 0, 0, 'Unknown']
# Processed MAR 79 rows: [501558.0, 'Gallano, Azenith', 'Alicante St.', nan, 2, 2, 0, 0, 'Connected']
# Processed APR 79 rows: [501558.0, 'Gallano, Azenith', 'Alicante St.', nan, 2, 2, 0, 0, 'Connected']
# Processed MAR 80 rows: [501690.0, 'Gallinera, John Mark', 'Alicante St.', nan, 41, 62, 21, 210, 'Connected']
# Processed APR 80 rows: [501690.0, 'Gallinera, John Mark', 'Alicante St.', nan, 62, 83, 21, 210, 'Connected']
# Processed MAR 81 rows: [501332.0, 'Gebelaguin, Jenlyn', 'Alicante St.', nan, 1379, 1379, 0, 0, 'Connected']
# Processed APR 81 rows: [501332.0, 'Gebelaguin, Jenlyn', 'Alicante St.', nan, 1379, 1379, 0, 0, 'Connected']
# Processed MAR 82 rows: [500711.0, 'Gebelaguin, Jesus', 'Alicante St.', nan, 858, 865, 7, 70, 'Connected']
# Processed APR 82 rows: [500711.0, 'Gebelaguin, Jesus', 'Alicante St.', nan, 865, 872, 7, 70, 'Connected']
# Processed MAR 83 rows: [501025.0, 'Gelotin, Gemma', 'Alicante St.', nan, 253, 267, 14, 140, 'Connected']
# Processed APR 83 rows: [501025.0, 'Gelotin, Gemma', 'Alicante St.', nan, 267, 282, 15, 150, 'Connected']
# Processed MAR 84 rows: [501023.0, 'Generoso, Ernesto', 'Alicante St.', nan, 27, 27, 0, 0, 'Connected']
# Processed APR 84 rows: [501023.0, 'Generoso, Ernesto', 'Alicante St.', nan, 27, 27, 0, 0, 'Connected']
# Processed MAR 85 rows: [501289.0, 'Gestole,Chosen', 'Alicante St.', nan, 1503, 1509, 6, 60, 'Connected']
# Processed APR 85 rows: [501289.0, 'Gestole,Chosen', 'Alicante St.', nan, 1509, 1514, 5, 50, 'Connected']
# Processed MAR 86 rows: [500461.0, 'Grencio, Ramir', 'Alicante St.', nan, 1503, 1503, 0, 0, 'Defect']
# Processed APR 86 rows: [500461.0, 'Grencio, Ramir', 'Alicante St.', nan, 1503, 1503, 0, 0, 'Defect']
# Processed MAR 87 rows: [500623.0, 'Grencio, Maribel', 'Alicante St.', nan, 191, 207, 16, 160, 'Connected']
# Processed APR 87 rows: [500623.0, 'Grencio, Maribel', 'Alicante St.', nan, 207, 224, 17, 170, 'Connected']
# Processed MAR 88 rows: [500008.0, 'Genova, Erlinda', 'Alicante St.', '966416', 1725, 1729, 4, 40, 'Connected']
# Processed APR 88 rows: [500008.0, 'Genova, Erlinda', 'Alicante St.', '966416', 1729, 1732, 3, 30, 'Connected']
# Processed MAR 89 rows: [500760.0, 'Gicaro, Efamar', 'Alicante St.', nan, 125, 131, 6, 60, 'Connected']
# Processed APR 89 rows: [500760.0, 'Gicaro, Efamar', 'Alicante St.', nan, 131, 137, 6, 60, 'Connected']
# Processed MAR 90 rows: [501306.0, 'Gulmatico, Rodel', 'Alicante St.', nan, 1068, 1081, 13, 130, 'Connected']
# Processed APR 90 rows: [501306.0, 'Gulmatico, Rodel', 'Alicante St.', nan, 1081, 1094, 13, 130, 'Connected']
# Processed MAR 91 rows: [501613.0, 'Gutierrez, Reynald', 'Alicante St.', nan, 403, 433, 30, 300, 'Connected']
# Processed APR 91 rows: [501613.0, 'Gutierrez, Reynald', 'Alicante St.', nan, 433, 464, 31, 310, 'Connected']
# Processed MAR 92 rows: [501518.0, 'Granado, Cecilia', 'Alicante St.', nan, 434, 436, 2, 20, 'Connected']
# Processed APR 92 rows: [501518.0, 'Granado, Cecilia', 'Alicante St.', nan, 436, 438, 2, 20, 'Connected']
# Processed MAR 93 rows: [501128.0, 'Ida, Marife', 'Alicante St.', nan, 478, 478, 0, 0, 'Connected']
# Processed APR 93 rows: [501128.0, 'Ida, Marife', 'Alicante St.', nan, 478, 478, 0, 0, 'Connected']
# Processed MAR 94 rows: [500010.0, 'Jardin, Eden', 'Alicante St.', '957121', 66, 74, 8, 80, 'Connected']
# Processed APR 94 rows: [500010.0, 'Jardin, Eden', 'Alicante St.', '957121', 74, 81, 7, 70, 'Connected']
# Processed MAR 95 rows: [500907.0, 'Javier, Elena', 'Alicante St.', nan, 1948, 1960, 12, 120, 'Connected']
# Processed APR 95 rows: [500907.0, 'Javier, Elena', 'Alicante St.', nan, 1960, 1971, 11, 110, 'Connected']
# Processed MAR 96 rows: [500910.0, 'Kingdom of Jehova\x92s Witnesses', 'Alicante St.', '027634-02', 1948, 1948, 0, 0, 'Unknown']
# Processed APR 96 rows: [500910.0, 'Kingdom of Jehova\x92s Witnesses', 'Alicante St.', '027634-02', 1948, 1948, 0, 0, 'Unknown']
# Processed MAR 97 rows: [500178.0, 'Laila, Vilma', 'Alicante St.', '6886956', 9023, 9085, 62, 620, 'Connected']
# Processed APR 97 rows: [500178.0, 'Laila, Vilma', 'Alicante St.', '6886956', 9085, 9147, 62, 620, 'Connected']
# Processed MAR 98 rows: [500559.0, 'Laurio, Josefa', 'Alicante St.', nan, 99, 105, 6, 60, 'Connected']
# Processed APR 98 rows: [500559.0, 'Laurio, Josefa', 'Alicante St.', nan, 105, 111, 6, 60, 'Connected']
# Processed MAR 99 rows: [500284.0, 'Leonor, Loreto (A)', 'Alicante St.', '205000532', 17042, 17209, 167, 1670, 'Connected']
# Processed APR 99 rows: [500284.0, 'Leonor, Loreto (A)', 'Alicante St.', '205000532', 17209, 17376, 167, 1670, 'Connected']
# Processed MAR 100 rows: [500378.0, 'Leonor, Loreto (B)/Rivero, Erwin', 'Alicante St.', '9588127', 287, 287, 0, 0, 'Connected']
# Processed APR 100 rows: [500378.0, 'Leonor, Loreto (B)/Rivero, Erwin', 'Alicante St.', '9588127', 287, 287, 0, 0, 'Connected']
# Processed MAR 101 rows: [500717.0, 'Letada, Gener', 'Alicante St.', '028114-02', 287, 287, 0, 0, 'Unknown']
# Processed APR 101 rows: [500717.0, 'Letada, Gener', 'Alicante St.', '028114-02', 287, 287, 0, 0, 'Unknown']
# Processed MAR 102 rows: [500013.0, 'Lique, Esteban', 'Alicante St.', '20500534', 3790, 3806, 16, 160, 'Connected']
# Processed APR 102 rows: [500013.0, 'Lique, Esteban', 'Alicante St.', '20500534', 3806, 3821, 15, 150, 'Connected']
# Processed MAR 103 rows: [500794.0, 'Llacer, Mary Grace', 'Alicante St.', nan, 328, 350, 22, 220, 'Connected']
# Processed APR 103 rows: [500794.0, 'Llacer, Mary Grace', 'Alicante St.', nan, 350, 373, 23, 230, 'Connected']
# Processed MAR 104 rows: [500408.0, 'Lumberio, Belinda', 'Alicante St.', nan, 5464, 5476, 12, 120, 'Connected']
# Processed APR 104 rows: [500408.0, 'Lumberio, Belinda', 'Alicante St.', nan, 5476, 5487, 11, 110, 'Connected']
# Processed MAR 105 rows: [500973.0, 'Lumberio, Belinda 2', 'Alicante St.', nan, 162, 165, 3, 30, 'Connected']
# Processed APR 105 rows: [500973.0, 'Lumberio, Belinda 2', 'Alicante St.', nan, 165, 168, 3, 30, 'Connected']
# Processed MAR 106 rows: [500475.0, 'Lumberio, Marvin', 'Alicante St.', nan, 516, 541, 25, 250, 'Connected']
# Processed APR 106 rows: [500475.0, 'Lumberio, Marvin', 'Alicante St.', nan, 541, 566, 25, 250, 'Connected']
# Processed MAR 107 rows: [500986.0, 'Lumberio, Ramon', 'Alicante St.', nan, 516, 516, 0, 0, 'Unknown']
# Processed APR 107 rows: [500986.0, 'Lumberio, Ramon', 'Alicante St.', nan, 516, 516, 0, 0, 'Unknown']
# Processed MAR 108 rows: [501344.0, 'Macabuhay, Henry', 'Alicante St.', nan, 140, 150, 10, 100, 'Connected']
# Processed APR 108 rows: [501344.0, 'Macabuhay, Henry', 'Alicante St.', nan, 150, 161, 11, 110, 'Connected']
# Processed MAR 109 rows: [500250.0, 'Macabuhay, Wilferdo', 'Alicante St.', '951511', 379, 411, 32, 320, 'Connected']
# Processed APR 109 rows: [500250.0, 'Macabuhay, Wilferdo', 'Alicante St.', '951511', 411, 443, 32, 320, 'Connected']
# Processed MAR 110 rows: [500789.0, 'Macoy, Cyrus', 'Alicante St.', '487', 502, 536, 34, 340, 'Connected']
# Processed APR 110 rows: [500789.0, 'Macoy, Cyrus', 'Alicante St.', '487', 536, 570, 34, 340, 'Connected']
# Processed MAR 111 rows: [500978.0, 'Magayanes, Ruel', 'Alicante St.', nan, 1678, 1691, 13, 130, 'Connected']
# Processed APR 111 rows: [500978.0, 'Magayanes, Ruel', 'Alicante St.', nan, 1691, 1704, 13, 130, 'Connected']
# Processed MAR 112 rows: [501620.0, 'Magdaraog, Felix III', 'Alicante St.', nan, 122, 122, 0, 0, 'Connected']
# Processed APR 112 rows: [501620.0, 'Magdaraog, Felix III', 'Alicante St.', nan, 122, 122, 0, 0, 'Connected']
# Processed MAR 113 rows: [500650.0, 'Martinez, Dante', 'Alicante St.', nan, 2531, 2546, 15, 150, 'Connected']
# Processed APR 113 rows: [500650.0, 'Martinez, Dante', 'Alicante St.', nan, 2546, 2561, 15, 150, 'Connected']
# Processed MAR 114 rows: [500980.0, 'Martinez, Vincent', 'Alicante St.', nan, 2531, 2531, 0, 0, 'Unknown']
# Processed APR 114 rows: [500980.0, 'Martinez, Vincent', 'Alicante St.', nan, 2531, 2531, 0, 0, 'Unknown']
# Processed MAR 115 rows: [501481.0, 'Mercado, Judith', 'Alicante St.', nan, 527, 565, 38, 380, 'Connected']
# Processed APR 115 rows: [501481.0, 'Mercado, Judith', 'Alicante St.', nan, 565, 604, 39, 390, 'Connected']
# Processed MAR 116 rows: [500271.0, 'Mores, Rosario', 'Alicante St.', nan, 527, 527, 0, 0, 'Unknown']
# Processed APR 116 rows: [500271.0, 'Mores, Rosario', 'Alicante St.', nan, 527, 527, 0, 0, 'Unknown']
# Processed MAR 117 rows: [500093.0, 'Moya, Crispina', 'Alicante St.', '017819-02', 1782, 1798, 16, 160, 'Connected']
# Processed APR 117 rows: [500093.0, 'Moya, Crispina', 'Alicante St.', '017819-02', 1798, 1815, 17, 170, 'Connected']
# Processed MAR 118 rows: [500839.0, 'Ontog, Chita', 'Alicante St.', '61222355', 3855, 3897, 42, 420, 'Connected']
# Processed APR 118 rows: [500839.0, 'Ontog, Chita', 'Alicante St.', '61222355', 3897, 3938, 41, 410, 'Connected']
# Processed MAR 119 rows: [501088.0, 'Pamotillo, Eva', 'Alicante St.', nan, 1729, 1741, 12, 120, 'Connected']
# Processed APR 119 rows: [501088.0, 'Pamotillo, Eva', 'Alicante St.', nan, 1741, 1754, 13, 130, 'Connected']
# Processed MAR 120 rows: [500265.0, 'Ramos, Doroteo', 'Alicante St.', nan, 1729, 1729, 0, 0, 'Unknown']
# Processed APR 120 rows: [500265.0, 'Ramos, Doroteo', 'Alicante St.', nan, 1729, 1729, 0, 0, 'Unknown']
# Processed MAR 121 rows: [500241.0, 'Recto, Nerissa', 'Alicante St.', '9005275', 3211, 3282, 71, 710, 'Connected']
# Processed APR 121 rows: [500241.0, 'Recto, Nerissa', 'Alicante St.', '9005275', 3282, 3353, 71, 710, 'Connected']
# Processed MAR 122 rows: [500270.0, 'Rejuso, Ceddy', 'Alicante St.', nan, 489, 510, 21, 210, 'Connected']
# Processed APR 122 rows: [500270.0, 'Rejuso, Ceddy', 'Alicante St.', nan, 510, 531, 21, 210, 'Connected']
# Processed MAR 123 rows: [501425.0, 'Rejuso, James', 'Alicante St.', nan, 622, 644, 22, 220, 'Connected']
# Processed APR 123 rows: [501425.0, 'Rejuso, James', 'Alicante St.', nan, 644, 667, 23, 230, 'Connected']
# Processed MAR 124 rows: [500011.0, 'Rico, Esperanza', 'Alicante St.', nan, 2063, 2072, 9, 90, 'Connected']
# Processed APR 124 rows: [500011.0, 'Rico, Esperanza', 'Alicante St.', nan, 2072, 2081, 9, 90, 'Connected']
# Processed MAR 125 rows: [500723.0, 'Rilles, Flordeliza', 'Alicante St.', nan, 2063, 2063, 0, 0, 'Disconnected']
# Processed APR 125 rows: [500723.0, 'Rilles, Flordeliza', 'Alicante St.', nan, 2063, 2063, 0, 0, 'Disconnected']
# Processed MAR 126 rows: [500487.0, 'Sese, Robert', 'Alicante St.', nan, 2063, 2063, 0, 0, 'Unknown']
# Processed APR 126 rows: [500487.0, 'Sese, Robert', 'Alicante St.', nan, 2063, 2063, 0, 0, 'Unknown']
# Processed MAR 127 rows: [500203.0, 'Sopsop, Evelyn', 'Alicante St.', nan, 1364, 1364, 0, 0, 'Connected']
# Processed APR 127 rows: [500203.0, 'Sopsop, Evelyn', 'Alicante St.', nan, 1364, 1364, 0, 0, 'Connected']
# Processed MAR 128 rows: [500941.0, 'Tarrobal, Amiel', 'Alicante St.', nan, 192, 194, 2, 20, 'Connected']
# Processed APR 128 rows: [500941.0, 'Tarrobal, Amiel', 'Alicante St.', nan, 194, 197, 3, 30, 'Connected']
# Processed MAR 129 rows: [500584.0, 'Tarrobal, Leny', 'Alicante St.', '954885', 3214, 3222, 8, 80, 'Connected']
# Processed APR 129 rows: [500584.0, 'Tarrobal, Leny', 'Alicante St.', '954885', 3222, 3231, 9, 90, 'Connected']
# Processed MAR 130 rows: [500368.0, 'Tugbo, Nixon', 'Alicante St.', '017734-02', 3600, 3611, 11, 110, 'Connected']
# Processed APR 130 rows: [500368.0, 'Tugbo, Nixon', 'Alicante St.', '017734-02', 3611, 3622, 11, 110, 'Connected']
# Processed MAR 131 rows: [500381.0, 'UCCP', 'Alicante St.', '955353', 6795, 6847, 52, 520, 'Connected']
# Processed APR 131 rows: [500381.0, 'UCCP', 'Alicante St.', '955353', 6847, 6898, 51, 510, 'Connected']
# Processed MAR 132 rows: [500911.0, 'Villahermosa, Benjamin', 'Alicante St.', '108022-02', 6795, 6795, 0, 0, 'Unknown']
# Processed APR 132 rows: [500911.0, 'Villahermosa, Benjamin', 'Alicante St.', '108022-02', 6795, 6795, 0, 0, 'Unknown']
# Processed MAR 133 rows: [500356.0, 'Villahermosa, Lita', 'Alicante St.', '96903254', 1050, 1054, 4, 40, 'Connected']
# Processed APR 133 rows: [500356.0, 'Villahermosa, Lita', 'Alicante St.', '96903254', 1054, 1057, 3, 30, 'Connected']
# Processed MAR 134 rows: [500170.0, 'Villahermosa, Pedro', 'Alicante St.', '027570-02', 3266, 3320, 54, 540, 'Connected']
# Processed APR 134 rows: [500170.0, 'Villahermosa, Pedro', 'Alicante St.', '027570-02', 3320, 3373, 53, 530, 'Connected']
# Processed MAR 135 rows: [500633.0, 'Villahermosa, Sonia', 'Alicante St.', '028508-02', 3266, 3266, 0, 0, 'Unknown']
# Processed APR 135 rows: [500633.0, 'Villahermosa, Sonia', 'Alicante St.', '028508-02', 3266, 3266, 0, 0, 'Unknown']
# Processed MAR 136 rows: [501428.0, 'Villahermosa, Jenny', 'Alicante St.', nan, 771, 797, 26, 260, 'Connected']
# Processed APR 136 rows: [501428.0, 'Villahermosa, Jenny', 'Alicante St.', nan, 797, 823, 26, 260, 'Connected']
# Processed MAR 137 rows: [500726.0, 'Villamor, Arne', 'Alicante St.', '1754', 394, 434, 40, 400, 'Connected']
# Processed APR 137 rows: [500726.0, 'Villamor, Arne', 'Alicante St.', '1754', 434, 473, 39, 390, 'Connected']
# Processed MAR 138 rows: [500984.0, 'Villamor, Belen', 'Alicante St.', '2834202', 371, 382, 11, 110, 'Connected']
# Processed APR 138 rows: [500984.0, 'Villamor, Belen', 'Alicante St.', '2834202', 382, 393, 11, 110, 'Connected']
# Processed MAR 139 rows: [501291.0, 'Herato, Jovelyn', 'Alicante St.', nan, 741, 745, 4, 40, 'Connected']
# Processed APR 139 rows: [501291.0, 'Herato, Jovelyn', 'Alicante St.', nan, 745, 750, 5, 50, 'Connected']
# Processed MAR 140 rows: [500399.0, 'Villamor, Emily', 'Alicante St.', '028342-02', 2518, 2518, 0, 0, 'Connected']
# Processed APR 140 rows: [500399.0, 'Villamor, Emily', 'Alicante St.', '028342-02', 2518, 2518, 0, 0, 'Connected']
# Processed MAR 141 rows: [501324.0, 'Villamor, Ricky', 'Alicante St.', nan, 391, 394, 3, 30, 'Connected']
# Processed APR 141 rows: [501324.0, 'Villamor, Ricky', 'Alicante St.', nan, 394, 397, 3, 30, 'Connected']
# Processed MAR 142 rows: [501219.0, 'Villamor,Fulceda', 'Alicante St.', '028145-02', 858, 866, 8, 80, 'Connected']
# Processed APR 142 rows: [501219.0, 'Villamor,Fulceda', 'Alicante St.', '028145-02', 866, 873, 7, 70, 'Connected']
# Processed MAR 143 rows: [500056.0, 'Villamor, Joel', 'Alicante St.', nan, 3244, 3262, 18, 180, 'Connected']
# Processed APR 143 rows: [500056.0, 'Villamor, Joel', 'Alicante St.', nan, 3262, 3279, 17, 170, 'Connected']
# Processed MAR 144 rows: [500683.0, 'Cañares, Marlon', 'Almonte St.', '017824-02', 3244, 3244, 0, 0, 'Disconnected']
# Processed APR 144 rows: [500683.0, 'Cañares, Marlon', 'Almonte St.', '017824-02', 3244, 3244, 0, 0, 'Disconnected']
# Processed MAR 145 rows: [501177.0, 'Delavin, Zonrico', 'Almonte St.', nan, 3244, 3244, 0, 0, 'Disconnected']
# Processed APR 145 rows: [501177.0, 'Delavin, Zonrico', 'Almonte St.', nan, 3244, 3244, 0, 0, 'Disconnected']
# Processed MAR 146 rows: [500815.0, 'Delavin, Zonrico 2', 'Almonte St.', nan, 3244, 3244, 0, 0, 'Disconnected']
# Processed APR 146 rows: [500815.0, 'Delavin, Zonrico 2', 'Almonte St.', nan, 3244, 3244, 0, 0, 'Disconnected']
# Processed MAR 147 rows: [501218.0, 'Delavin, Zonrico 3', 'Almonte St.', nan, 3244, 3244, 0, 0, 'Disconnected']
# Processed APR 147 rows: [501218.0, 'Delavin, Zonrico 3', 'Almonte St.', nan, 3244, 3244, 0, 0, 'Disconnected']
# Processed MAR 148 rows: [501067.0, 'Espenilla, Marina', 'Almonte St.', nan, 3244, 3244, 0, 0, 'Defect']
# Processed APR 148 rows: [501067.0, 'Espenilla, Marina', 'Almonte St.', nan, 3244, 3244, 0, 0, 'Defect']
# Processed MAR 149 rows: [500983.0, 'Espinosa, Aris', 'Almonte St.', '17768', 7836, 7869, 33, 330, 'Connected']
# Processed APR 149 rows: [500983.0, 'Espinosa, Aris', 'Almonte St.', '17768', 7869, 7902, 33, 330, 'Connected']
# Processed MAR 150 rows: [500988.0, 'JMH Foundation Inc.', 'Almonte St.', nan, 7836, 7836, 0, 0, 'Disconnected']
# Processed APR 150 rows: [500988.0, 'JMH Foundation Inc.', 'Almonte St.', nan, 7836, 7836, 0, 0, 'Disconnected']
# Processed MAR 151 rows: [501294.0, 'Liceo De Sn. Jto. c/o Atty. Merillo', 'Almonte St.', nan, 3371, 3371, 0, 0, 'Connected']
# Processed APR 151 rows: [501294.0, 'Liceo De Sn. Jto. c/o Atty. Merillo', 'Almonte St.', nan, 3371, 3371, 0, 0, 'Connected']
# Processed MAR 152 rows: [500082.0, 'LSJ', 'Almonte St.', '017814-02', 7291, 7419, 128, 1280, 'Connected']
# Processed APR 152 rows: [500082.0, 'LSJ', 'Almonte St.', '017814-02', 7419, 7547, 128, 1280, 'Connected']
# Processed MAR 153 rows: [501450.0, 'Macoy, Besilda', 'Almonte St.', '018035-02', 5376, 5792, 416, 4160, 'Connected']
# Processed APR 153 rows: [501450.0, 'Macoy, Besilda', 'Almonte St.', '018035-02', 5792, 6209, 417, 4170, 'Connected']
# Processed MAR 154 rows: [501285.0, 'Omilgo, Michelle', 'Almonte St.', '12-125484', 1011, 1072, 61, 610, 'Connected']
# Processed APR 154 rows: [501285.0, 'Omilgo, Michelle', 'Almonte St.', '12-125484', 1072, 1133, 61, 610, 'Connected']
# Processed MAR 155 rows: [500832.0, 'Laila, Aida Marie', 'Almonte St.', '027976-02', 8731, 8731, 0, 0, 'Connected']
# Processed APR 155 rows: [500832.0, 'Laila, Aida Marie', 'Almonte St.', '027976-02', 8731, 8731, 0, 0, 'Connected']
# Processed MAR 156 rows: [501529.0, 'LSJFI NEW BLDG', 'Almonte St.', nan, 714, 806, 92, 920, 'Connected']
# Processed APR 156 rows: [501529.0, 'LSJFI NEW BLDG', 'Almonte St.', nan, 806, 899, 93, 930, 'Connected']
# Processed MAR 157 rows: [500118.0, 'Abejero, Ernesto Jr.', 'Altarejos St.', '017147-02', 6260, 6289, 29, 290, 'Connected']
# Processed APR 157 rows: [500118.0, 'Abejero, Ernesto Jr.', 'Altarejos St.', '017147-02', 6289, 6318, 29, 290, 'Connected']
# Processed MAR 158 rows: [501241.0, 'Amante, Nerissa', 'Altarejos St.', nan, 1593, 1605, 12, 120, 'Connected']
# Processed APR 158 rows: [501241.0, 'Amante, Nerissa', 'Altarejos St.', nan, 1605, 1618, 13, 130, 'Connected']
# Processed MAR 159 rows: [500072.0, 'Alcantara, Rector', 'Altarejos St.', '151748', 2143, 2143, 0, 0, 'Connected']
# Processed APR 159 rows: [500072.0, 'Alcantara, Rector', 'Altarejos St.', '151748', 2143, 2143, 0, 0, 'Connected']
# Processed MAR 160 rows: [500810.0, 'Almerol, Nilo', 'Altarejos St.', nan, 191, 199, 8, 80, 'Connected']
# Processed APR 160 rows: [500810.0, 'Almerol, Nilo', 'Altarejos St.', nan, 199, 208, 9, 90, 'Connected']
# Processed MAR 161 rows: [501534.0, 'Almiñe, Nixon', 'Altarejos St.', nan, 14, 15, 1, 10, 'Connected']
# Processed APR 161 rows: [501534.0, 'Almiñe, Nixon', 'Altarejos St.', nan, 15, 16, 1, 10, 'Connected']
# Processed MAR 162 rows: [500447.0, 'Almodiel, Fe', 'Altarejos St.', '151660', 6309, 6325, 16, 160, 'Connected']
# Processed APR 162 rows: [500447.0, 'Almodiel, Fe', 'Altarejos St.', '151660', 6325, 6341, 16, 160, 'Connected']
# Processed MAR 163 rows: [500809.0, 'Almodiel, Merly', 'Altarejos St.', '798', 1527, 1533, 6, 60, 'Connected']
# Processed APR 163 rows: [500809.0, 'Almodiel, Merly', 'Altarejos St.', '798', 1533, 1539, 6, 60, 'Connected']
# Processed MAR 164 rows: [500483.0, 'Almoete, Aleli', 'Altarejos St.', '9588453', 688, 698, 10, 100, 'Connected']
# Processed APR 164 rows: [500483.0, 'Almoete, Aleli', 'Altarejos St.', '9588453', 698, 707, 9, 90, 'Connected']
# Processed MAR 165 rows: [500443.0, 'Almoete, Arles', 'Altarejos St.', '028661-02', 2341, 2341, 0, 0, 'Connected']
# Processed APR 165 rows: [500443.0, 'Almoete, Arles', 'Altarejos St.', '028661-02', 2341, 2341, 0, 0, 'Connected']
# Processed MAR 166 rows: [501474.0, 'Almonte, Michelle', 'Altarejos St.', nan, 460, 476, 16, 160, 'Connected']
# Processed APR 166 rows: [501474.0, 'Almonte, Michelle', 'Altarejos St.', nan, 476, 491, 15, 150, 'Connected']
# Processed MAR 167 rows: [500215.0, 'Almojuela, Junie', 'Altarejos St.', '151758', 127, 135, 8, 80, 'Connected']
# Processed APR 167 rows: [500215.0, 'Almojuela, Junie', 'Altarejos St.', '151758', 135, 144, 9, 90, 'Connected']
# Processed MAR 168 rows: [500043.0, 'Almojuela, Segundino', 'Altarejos St.', '017239-02', 1956, 1958, 2, 20, 'Connected']
# Processed APR 168 rows: [500043.0, 'Almojuela, Segundino', 'Altarejos St.', '017239-02', 1958, 1960, 2, 20, 'Connected']
# Processed MAR 169 rows: [501645.0, 'Almoradie, Jose', 'Altarejos St.', nan, 31, 47, 16, 160, 'Connected']
# Processed APR 169 rows: [501645.0, 'Almoradie, Jose', 'Altarejos St.', nan, 47, 63, 16, 160, 'Connected']
# Processed MAR 170 rows: [500149.0, 'Atabay, Elisa', 'Altarejos St.', '44935', 31, 31, 0, 0, 'Disconnected']
# Processed APR 170 rows: [500149.0, 'Atabay, Elisa', 'Altarejos St.', '44935', 31, 31, 0, 0, 'Disconnected']
# Processed MAR 171 rows: [500741.0, 'Arevalo, Amy', 'Altarejos St.', '029107-02', 102, 58, -44, -440, 'Connected']
# Processed APR 171 rows: [500741.0, 'Arevalo, Amy', 'Altarejos St.', '029107-02', 58, 14, -44, -440, 'Connected']
# Processed MAR 172 rows: [501026.0, 'Barrun, Ana', 'Altarejos St.', nan, 293, 321, 28, 280, 'Connected']
# Processed APR 172 rows: [501026.0, 'Barrun, Ana', 'Altarejos St.', nan, 321, 348, 27, 270, 'Connected']
# Processed MAR 173 rows: [500164.0, 'Barrun, Consolador', 'Altarejos St.', '017873-02', 293, 293, 0, 0, 'Disconnected']
# Processed APR 173 rows: [500164.0, 'Barrun, Consolador', 'Altarejos St.', '017873-02', 293, 293, 0, 0, 'Disconnected']
# Processed MAR 174 rows: [501216.0, 'Barrun, Panina', 'Altarejos St.', nan, 1374, 1394, 20, 200, 'Connected']
# Processed APR 174 rows: [501216.0, 'Barrun, Panina', 'Altarejos St.', nan, 1394, 1414, 20, 200, 'Connected']
# Processed MAR 175 rows: [500836.0, 'Barrun, Roderico', 'Altarejos St.', nan, 1374, 1374, 0, 0, 'Unknown']
# Processed APR 175 rows: [500836.0, 'Barrun, Roderico', 'Altarejos St.', nan, 1374, 1374, 0, 0, 'Unknown']
# Processed MAR 176 rows: [501667.0, 'Barrun, Siony', 'Altarejos St.', nan, 20, 20, 0, 0, 'Connected']
# Processed APR 176 rows: [501667.0, 'Barrun, Siony', 'Altarejos St.', nan, 20, 20, 0, 0, 'Connected']
# Processed MAR 177 rows: [500258.0, 'Barrun, Ronnie/Barrun, Jerson', 'Altarejos St.', '018061-02', 829, 853, 24, 240, 'Connected']
# Processed APR 177 rows: [500258.0, 'Barrun, Ronnie/Barrun, Jerson', 'Altarejos St.', '018061-02', 853, 878, 25, 250, 'Connected']
# Processed MAR 178 rows: [500824.0, 'Bartolata, Adolfo', 'Altarejos St.', nan, 829, 829, 0, 0, 'Disconnected']
# Processed APR 178 rows: [500824.0, 'Bartolata, Adolfo', 'Altarejos St.', nan, 829, 829, 0, 0, 'Disconnected']
# Processed MAR 179 rows: [501494.0, 'Bartolata, Antonio', 'Altarejos St.', nan, 2586, 2613, 27, 270, 'Connected']
# Processed APR 179 rows: [501494.0, 'Bartolata, Antonio', 'Altarejos St.', nan, 2613, 2640, 27, 270, 'Connected']
# Processed MAR 180 rows: [500551.0, 'Bartolata, Danilo', 'Altarejos St.', nan, 6982, 7022, 40, 400, 'Connected']
# Processed APR 180 rows: [500551.0, 'Bartolata, Danilo', 'Altarejos St.', nan, 7022, 7061, 39, 390, 'Connected']
# Processed MAR 181 rows: [501487.0, 'Bartolata, Felicisima', 'Altarejos St.', nan, 3474, 3510, 36, 360, 'Connected']
# Processed APR 181 rows: [501487.0, 'Bartolata, Felicisima', 'Altarejos St.', nan, 3510, 3545, 35, 350, 'Connected']
# Processed MAR 182 rows: [500205.0, 'Bartolata, Melchor', 'Altarejos St.', '028917-02', 2186, 2188, 2, 20, 'Connected']
# Processed APR 182 rows: [500205.0, 'Bartolata, Melchor', 'Altarejos St.', '028917-02', 2188, 2189, 1, 10, 'Connected']
# Processed MAR 183 rows: [500595.0, 'Bartolay, Albert', 'Altarejos St.', '017828-02', 1964, 1973, 9, 90, 'Connected']
# Processed APR 183 rows: [500595.0, 'Bartolay, Albert', 'Altarejos St.', '017828-02', 1973, 1982, 9, 90, 'Connected']
# Processed MAR 184 rows: [501027.0, 'Bartolay, Diosdado', 'Altarejos St.', nan, 930, 940, 10, 100, 'Connected']
# Processed APR 184 rows: [501027.0, 'Bartolay, Diosdado', 'Altarejos St.', nan, 940, 951, 11, 110, 'Connected']
# Processed MAR 185 rows: [500158.0, 'Bartolay, Dominador', 'Altarejos St.', '9310910', 469, 469, 0, 0, 'Connected']
# Processed APR 185 rows: [500158.0, 'Bartolay, Dominador', 'Altarejos St.', '9310910', 469, 469, 0, 0, 'Connected']
# Processed MAR 186 rows: [500071.0, 'Bartolay, Licel', 'Altarejos St.', '017816-02', 16199, 16307, 108, 1080, 'Connected']
# Processed APR 186 rows: [500071.0, 'Bartolay, Licel', 'Altarejos St.', '017816-02', 16307, 16416, 109, 1090, 'Connected']
# Processed MAR 187 rows: [501415.0, 'Bartolay, Roald', 'Altarejos St.', nan, 191, 194, 3, 30, 'Connected']
# Processed APR 187 rows: [501415.0, 'Bartolay, Roald', 'Altarejos St.', nan, 194, 197, 3, 30, 'Connected']
# Processed MAR 188 rows: [500204.0, 'Bartolay, Victor', 'Altarejos St.', '301748', 186, 202, 16, 160, 'Connected']
# Processed APR 188 rows: [500204.0, 'Bartolay, Victor', 'Altarejos St.', '301748', 202, 218, 16, 160, 'Connected']
# Processed MAR 189 rows: [501419.0, 'Cabiles, Solon', 'Altarejos St.', nan, 1284, 1344, 60, 600, 'Connected']
# Processed APR 189 rows: [501419.0, 'Cabiles, Solon', 'Altarejos St.', nan, 1344, 1405, 61, 610, 'Connected']
# Processed MAR 190 rows: [500200.0, 'Cantre, Vilma', 'Altarejos St.', '017880-02', 2321, 2331, 10, 100, 'Connected']
# Processed APR 190 rows: [500200.0, 'Cantre, Vilma', 'Altarejos St.', '017880-02', 2331, 2342, 11, 110, 'Connected']
# Processed MAR 191 rows: [500888.0, 'Carillo, Mida', 'Altarejos St.', '027637-02', 984, 984, 0, 0, 'Connected']
# Processed APR 191 rows: [500888.0, 'Carillo, Mida', 'Altarejos St.', '027637-02', 984, 984, 0, 0, 'Connected']
# Processed MAR 192 rows: [501165.0, 'Dejumo, Adam', 'Altarejos St.', nan, 984, 984, 0, 0, 'Disconnected']
# Processed APR 192 rows: [501165.0, 'Dejumo, Adam', 'Altarejos St.', nan, 984, 984, 0, 0, 'Disconnected']
# Processed MAR 193 rows: [500719.0, 'Dejumo, Rowena', 'Altarejos St.', '18060', 984, 984, 0, 0, 'Disconnected']
# Processed APR 193 rows: [500719.0, 'Dejumo, Rowena', 'Altarejos St.', '18060', 984, 984, 0, 0, 'Disconnected']
# Processed MAR 194 rows: [500144.0, 'Delariarte, Evelyn', 'Altarejos St.', '018070-02', 619, 641, 22, 220, 'Connected']
# Processed APR 194 rows: [500144.0, 'Delariarte, Evelyn', 'Altarejos St.', '018070-02', 641, 663, 22, 220, 'Connected']
# Processed MAR 195 rows: [501077.0, 'Delariarte, Jenel', 'Altarejos St.', nan, 947, 963, 16, 160, 'Connected']
# Processed APR 195 rows: [501077.0, 'Delariarte, Jenel', 'Altarejos St.', nan, 963, 978, 15, 150, 'Connected']
# Processed MAR 196 rows: [500156.0, 'Delariarte, Vibiana', 'Altarejos St.', '44826', 2960, 2978, 18, 180, 'Connected']
# Processed APR 196 rows: [500156.0, 'Delariarte, Vibiana', 'Altarejos St.', '44826', 2978, 2997, 19, 190, 'Connected']
# Processed MAR 197 rows: [500805.0, 'Delavin, Seth', 'Altarejos St.', '027826-02', 3362, 3366, 4, 40, 'Connected']
# Processed APR 197 rows: [500805.0, 'Delavin, Seth', 'Altarejos St.', '027826-02', 3366, 3369, 3, 30, 'Connected']
# Processed MAR 198 rows: [500652.0, 'Delfin, Nena Fatima', 'Altarejos St.', nan, 3955, 3982, 27, 270, 'Connected']
# Processed APR 198 rows: [500652.0, 'Delfin, Nena Fatima', 'Altarejos St.', nan, 3982, 4009, 27, 270, 'Connected']
# Processed MAR 199 rows: [500948.0, 'Delos Santos, Nena', 'Altarejos St.', '017802-02', 3955, 3955, 0, 0, 'Unknown']
# Processed APR 199 rows: [500948.0, 'Delos Santos, Nena', 'Altarejos St.', '017802-02', 3955, 3955, 0, 0, 'Unknown']
# Processed MAR 200 rows: [500933.0, 'Española, Lourdes', 'Altarejos St.', '017032-02', 2935, 2949, 14, 140, 'Connected']
# Processed APR 200 rows: [500933.0, 'Española, Lourdes', 'Altarejos St.', '017032-02', 2949, 2963, 14, 140, 'Connected']
# Processed MAR 201 rows: [500155.0, 'Esparrago, Melchor', 'Altarejos St.', '95799', 2613, 2633, 20, 200, 'Connected']
# Processed APR 201 rows: [500155.0, 'Esparrago, Melchor', 'Altarejos St.', '95799', 2633, 2653, 20, 200, 'Connected']
# Processed MAR 202 rows: [500534.0, 'Espenilla, Eden', 'Altarejos St.', nan, 2613, 2613, 0, 0, 'Disconnected']
# Processed APR 202 rows: [500534.0, 'Espenilla, Eden', 'Altarejos St.', nan, 2613, 2613, 0, 0, 'Disconnected']
# Processed MAR 203 rows: [500137.0, 'Espinosa, Ader', 'Altarejos St.', '028191-02', 5315, 5329, 14, 140, 'Connected']
# Processed APR 203 rows: [500137.0, 'Espinosa, Ader', 'Altarejos St.', '028191-02', 5329, 5342, 13, 130, 'Connected']
# Processed MAR 204 rows: [500587.0, 'Espinosa, Jerol', 'Altarejos St.', nan, 3081, 3083, 2, 20, 'Connected']
# Processed APR 204 rows: [500587.0, 'Espinosa, Jerol', 'Altarejos St.', nan, 3083, 3084, 1, 10, 'Connected']
# Processed MAR 205 rows: [501089.0, 'Espinosa, Jerol (B)', 'Altarejos St.', nan, 4354, 4360, 6, 60, 'Connected']
# Processed APR 205 rows: [501089.0, 'Espinosa, Jerol (B)', 'Altarejos St.', nan, 4360, 4365, 5, 50, 'Connected']
# Processed MAR 206 rows: [500069.0, 'Espinosa, Tito', 'Altarejos St.', '957116', 191, 216, 25, 250, 'Connected']
# Processed APR 206 rows: [500069.0, 'Espinosa, Tito', 'Altarejos St.', '957116', 216, 241, 25, 250, 'Connected']
# Processed MAR 207 rows: [501153.0, 'Garamay, Eugene', 'Altarejos St.', 'H19487', 429, 448, 19, 190, 'Connected']
# Processed APR 207 rows: [501153.0, 'Garamay, Eugene', 'Altarejos St.', 'H19487', 448, 467, 19, 190, 'Connected']
# Processed MAR 208 rows: [500117.0, 'Garamay, Pio', 'Altarejos St.', '017235-02', 2932, 2964, 32, 320, 'Connected']
# Processed APR 208 rows: [500117.0, 'Garamay, Pio', 'Altarejos St.', '017235-02', 2964, 2995, 31, 310, 'Connected']
# Processed MAR 209 rows: [500982.0, 'Genova, Amilyn', 'Altarejos St.', nan, 1158, 1176, 18, 180, 'Connected']
# Processed APR 209 rows: [500982.0, 'Genova, Amilyn', 'Altarejos St.', nan, 1176, 1194, 18, 180, 'Connected']
# Processed MAR 210 rows: [500766.0, 'Grafilo, Remedios', 'Altarejos St.', nan, 1426, 1433, 7, 70, 'Connected']
# Processed APR 210 rows: [500766.0, 'Grafilo, Remedios', 'Altarejos St.', nan, 1433, 1440, 7, 70, 'Connected']
# Processed MAR 211 rows: [500199.0, 'Laila, Eugene', 'Altarejos St.', '954257', 1426, 1426, 0, 0, 'Unknown']
# Processed APR 211 rows: [500199.0, 'Laila, Eugene', 'Altarejos St.', '954257', 1426, 1426, 0, 0, 'Unknown']
# Processed MAR 212 rows: [500171.0, 'Letada, Felomino', 'Altarejos St.', '027563-02', 3533, 3553, 20, 200, 'Connected']
# Processed APR 212 rows: [500171.0, 'Letada, Felomino', 'Altarejos St.', '027563-02', 3553, 3572, 19, 190, 'Connected']
# Processed MAR 213 rows: [500105.0, 'Lignes, Maria', 'Altarejos St.', '95744', 6656, 6738, 82, 820, 'Connected']
# Processed APR 213 rows: [500105.0, 'Lignes, Maria', 'Altarejos St.', '95744', 6738, 6820, 82, 820, 'Connected']
# Processed MAR 214 rows: [500822.0, 'Lique, Amalia', 'Altarejos St.', '017236-02', 2744, 2768, 24, 240, 'Connected']
# Processed APR 214 rows: [500822.0, 'Lique, Amalia', 'Altarejos St.', '017236-02', 2768, 2793, 25, 250, 'Connected']
# Processed MAR 215 rows: [500590.0, 'Lumberio, Caridad', 'Altarejos St.', '017821-02', 2744, 4900, 2156, 21560, 'Defect']
# Processed APR 215 rows: [500590.0, 'Lumberio, Caridad', 'Altarejos St.', '017821-02', 4900, 7057, 2157, 21570, 'Defect']
# Processed MAR 216 rows: [500186.0, 'Marcos, Angelica', 'Altarejos St.', '957970', 28, 41, 13, 130, 'Connected']
# Processed APR 216 rows: [500186.0, 'Marcos, Angelica', 'Altarejos St.', '957970', 41, 54, 13, 130, 'Connected']
# Processed MAR 217 rows: [500596.0, 'Miña, Marife', 'Altarejos St.', '2493', 334, 354, 20, 200, 'Connected']
# ...
# Processed APR 1560 rows: [500175.0, 'Gernale, Ma. Naty', 'Moyot St.', nan, 3003, 3010, 7, 70, 'Connected']
# Processed MAR 1561 rows: [501389.0, 'Grencio, Joel', 'Moyot St.', nan, 2996, 2996, 0, 0, 'Defect']
# Processed APR 1561 rows: [501389.0, 'Grencio, Joel', 'Moyot St.', nan, 2996, 2996, 0, 0, 'Defect']
# Processed MAR 1562 rows: [501179.0, 'Giray Josephine', 'Moyot St.', '10087010', 2996, 2996, 0, 0, 'Defect']
# Processed APR 1562 rows: [501179.0, 'Giray Josephine', 'Moyot St.', '10087010', 2996, 2996, 0, 0, 'Defect']
# Processed MAR 1563 rows: [501609.0, 'Gois, Mary Grace', 'Moyot St.', nan, 246, 285, 39, 390, 'Connected']
# Processed APR 1563 rows: [501609.0, 'Gois, Mary Grace', 'Moyot St.', nan, 285, 324, 39, 390, 'Connected']
# Processed MAR 1564 rows: [500189.0, 'Guarnes, Nove', 'Moyot St.', '027561-02', 1571, 1577, 6, 60, 'Connected']
# Processed APR 1564 rows: [500189.0, 'Guarnes, Nove', 'Moyot St.', '027561-02', 1577, 1582, 5, 50, 'Connected']
# Processed MAR 1565 rows: [500677.0, 'Gutierrez, Evelyn', 'Moyot St.', nan, 2121, 2341, 220, 2200, 'Connected']
# Processed APR 1565 rows: [500677.0, 'Gutierrez, Evelyn', 'Moyot St.', nan, 2341, 2561, 220, 2200, 'Connected']
# Processed MAR 1566 rows: [501603.0, 'Gutierrez, Elvisa', 'Moyot St.', nan, 502, 571, 69, 690, 'Connected']
# Processed APR 1566 rows: [501603.0, 'Gutierrez, Elvisa', 'Moyot St.', nan, 571, 640, 69, 690, 'Connected']
# Processed MAR 1567 rows: [500016.0, 'Gutierrez, Robert', 'Moyot St.', '028458-02', 1975, 1975, 0, 0, 'Connected']
# Processed APR 1567 rows: [500016.0, 'Gutierrez, Robert', 'Moyot St.', '028458-02', 1975, 1975, 0, 0, 'Connected']
# Processed MAR 1568 rows: [501483.0, 'Hayohay, Muriel', 'Moyot St.', nan, 2901, 2925, 24, 240, 'Connected']
# Processed APR 1568 rows: [501483.0, 'Hayohay, Muriel', 'Moyot St.', nan, 2925, 2949, 24, 240, 'Connected']
# Processed MAR 1569 rows: [501627.0, 'Jardin, Elisa', 'Moyot St.', nan, 311, 365, 54, 540, 'Connected']
# Processed APR 1569 rows: [501627.0, 'Jardin, Elisa', 'Moyot St.', nan, 365, 418, 53, 530, 'Connected']
# Processed MAR 1570 rows: [501611.0, 'Lado, Eleonor', 'Moyot St.', nan, 209, 231, 22, 220, 'Connected']
# Processed APR 1570 rows: [501611.0, 'Lado, Eleonor', 'Moyot St.', nan, 231, 254, 23, 230, 'Connected']
# Processed MAR 1571 rows: [500853.0, 'Latagan, David', 'Moyot St.', '5277', 1590, 1590, 0, 0, 'Connected']
# Processed APR 1571 rows: [500853.0, 'Latagan, David', 'Moyot St.', '5277', 1590, 1590, 0, 0, 'Connected']
# Processed MAR 1572 rows: [500601.0, 'Laureano, Rane', 'Moyot St.', nan, 3102, 3139, 37, 370, 'Connected']
# Processed APR 1572 rows: [500601.0, 'Laureano, Rane', 'Moyot St.', nan, 3139, 3176, 37, 370, 'Connected']
# Processed MAR 1573 rows: [500054.0, 'Leonino, Fe', 'Moyot St.', '028454-02', 1901, 1917, 16, 160, 'Connected']
# Processed APR 1573 rows: [500054.0, 'Leonino, Fe', 'Moyot St.', '028454-02', 1917, 1932, 15, 150, 'Connected']
# Processed MAR 1574 rows: [500439.0, 'Leyco, Elena', 'Moyot St.', '957491', 2242, 2266, 24, 240, 'Connected']
# Processed APR 1574 rows: [500439.0, 'Leyco, Elena', 'Moyot St.', '957491', 2266, 2291, 25, 250, 'Connected']
# Processed MAR 1575 rows: [501622.0, 'Ligbao, Nora', 'Moyot St.', nan, 141, 157, 16, 160, 'Connected']
# Processed APR 1575 rows: [501622.0, 'Ligbao, Nora', 'Moyot St.', nan, 157, 174, 17, 170, 'Connected']
# Processed MAR 1576 rows: [500051.0, 'Lignes, Nena', 'Moyot St.', '325847', 141, 141, 0, 0, 'Unknown']
# Processed APR 1576 rows: [500051.0, 'Lignes, Nena', 'Moyot St.', '325847', 141, 141, 0, 0, 'Unknown']
# Processed MAR 1577 rows: [501628.0, 'Lique, Nida', 'Moyot St.', nan, 231, 265, 34, 340, 'Connected']
# Processed APR 1577 rows: [501628.0, 'Lique, Nida', 'Moyot St.', nan, 265, 300, 35, 350, 'Connected']
# Processed MAR 1578 rows: [500568.0, 'LBES', 'Moyot St.', nan, 1144, 1182, 38, 380, 'Connected']
# Processed APR 1578 rows: [500568.0, 'LBES', 'Moyot St.', nan, 1182, 1219, 37, 370, 'Connected']
# Processed MAR 1579 rows: [500808.0, 'Jaingue, Emma', 'Moyot St.', '878199', 70, 73, 3, 30, 'Connected']
# Processed APR 1579 rows: [500808.0, 'Jaingue, Emma', 'Moyot St.', '878199', 73, 76, 3, 30, 'Connected']
# Processed MAR 1580 rows: [501343.0, 'Macoy, Marilou', 'Moyot St.', '13033223', 1384, 1384, 0, 0, 'Connected']
# Processed APR 1580 rows: [501343.0, 'Macoy, Marilou', 'Moyot St.', '13033223', 1384, 1384, 0, 0, 'Connected']
# Processed MAR 1581 rows: [501354.0, 'Mahusay, Gina', 'Moyot St.', nan, 1384, 1384, 0, 0, 'Unknown']
# Processed APR 1581 rows: [501354.0, 'Mahusay, Gina', 'Moyot St.', nan, 1384, 1384, 0, 0, 'Unknown']
# Processed MAR 1582 rows: [501103.0, 'Malana, Elvie 2', 'Moyot St.', '1071820', 505, 541, 36, 360, 'Connected']
# Processed APR 1582 rows: [501103.0, 'Malana, Elvie 2', 'Moyot St.', '1071820', 541, 578, 37, 370, 'Connected']
# Processed MAR 1583 rows: [501302.0, 'Malana, Elvie 3', 'Moyot St.', '11-11-0810', 1065, 1169, 104, 1040, 'Connected']
# Processed APR 1583 rows: [501302.0, 'Malana, Elvie 3', 'Moyot St.', '11-11-0810', 1169, 1274, 105, 1050, 'Connected']
# Processed MAR 1584 rows: [500329.0, 'Malana, Renerio', 'Moyot St.', '32481', 11, 11, 0, 0, 'Connected']
# Processed APR 1584 rows: [500329.0, 'Malana, Renerio', 'Moyot St.', '32481', 11, 11, 0, 0, 'Connected']
# Processed MAR 1585 rows: [501305.0, 'Merillo, Napoleon', 'Moyot St.', '17-111-A64', 287, 307, 20, 200, 'Connected']
# Processed APR 1585 rows: [501305.0, 'Merillo, Napoleon', 'Moyot St.', '17-111-A64', 307, 326, 19, 190, 'Connected']
# Processed MAR 1586 rows: [501417.0, 'Monasterio, Angelina', 'Moyot St.', nan, 560, 562, 2, 20, 'Connected']
# Processed APR 1586 rows: [501417.0, 'Monasterio, Angelina', 'Moyot St.', nan, 562, 565, 3, 30, 'Connected']
# Processed MAR 1587 rows: [501551.0, 'Omilgo, Michelle', 'Moyot St.', nan, 399, 430, 31, 310, 'Connected']
# Processed APR 1587 rows: [501551.0, 'Omilgo, Michelle', 'Moyot St.', nan, 430, 461, 31, 310, 'Connected']
# Processed MAR 1588 rows: [500894.0, 'Ongonion, Crisanto', 'Moyot St.', '027638-02', 1998, 2001, 3, 30, 'Connected']
# Processed APR 1588 rows: [500894.0, 'Ongonion, Crisanto', 'Moyot St.', '027638-02', 2001, 2004, 3, 30, 'Connected']
# Processed MAR 1589 rows: [500039.0, 'Ongonion, Leonora', 'Moyot St.', '950007', 1795, 1795, 0, 0, 'Connected']
# Processed APR 1589 rows: [500039.0, 'Ongonion, Leonora', 'Moyot St.', '950007', 1795, 1795, 0, 0, 'Connected']
# Processed MAR 1590 rows: [501231.0, 'Oraa, Editha', 'Moyot St.', '11125457', 1795, 1795, 0, 0, 'Disconnected']
# Processed APR 1590 rows: [501231.0, 'Oraa, Editha', 'Moyot St.', '11125457', 1795, 1795, 0, 0, 'Disconnected']
# Processed MAR 1591 rows: [500131.0, 'Palermo, Norie', 'Moyot St.', '017149-02', 1359, 1400, 41, 410, 'Connected']
# Processed APR 1591 rows: [500131.0, 'Palermo, Norie', 'Moyot St.', '017149-02', 1400, 1441, 41, 410, 'Connected']
# Processed MAR 1592 rows: [501358.0, 'Pontalba, Joel', 'Moyot St.', '029079-02', 3312, 3466, 154, 1540, 'Connected']
# Processed APR 1592 rows: [501358.0, 'Pontalba, Joel', 'Moyot St.', '029079-02', 3466, 3620, 154, 1540, 'Connected']
# Processed MAR 1593 rows: [501107.0, 'Pura, Leny', 'Moyot St.', '704121', 3312, 3312, 0, 0, 'Unknown']
# Processed APR 1593 rows: [501107.0, 'Pura, Leny', 'Moyot St.', '704121', 3312, 3312, 0, 0, 'Unknown']
# Processed MAR 1594 rows: [500018.0, 'Quijano, Asteria', 'Moyot St.', '971208799', 4494, 4540, 46, 460, 'Connected']
# Processed APR 1594 rows: [500018.0, 'Quijano, Asteria', 'Moyot St.', '971208799', 4540, 4586, 46, 460, 'Connected']
# Processed MAR 1595 rows: [501478.0, 'Rejuso, Andres', 'Moyot St.', nan, 4494, 4494, 0, 0, 'Unknown']
# Processed APR 1595 rows: [501478.0, 'Rejuso, Andres', 'Moyot St.', nan, 4494, 4494, 0, 0, 'Unknown']
# Processed MAR 1596 rows: [500959.0, 'Rejuso, Arnold', 'Moyot St.', '017810-02', 4494, 4494, 0, 0, 'Unknown']
# Processed APR 1596 rows: [500959.0, 'Rejuso, Arnold', 'Moyot St.', '017810-02', 4494, 4494, 0, 0, 'Unknown']
# Processed MAR 1597 rows: [500844.0, 'Rosero, Frangie', 'Moyot St.', '9073243', 1178, 1246, 68, 680, 'Connected']
# Processed APR 1597 rows: [500844.0, 'Rosero, Frangie', 'Moyot St.', '9073243', 1246, 1313, 67, 670, 'Connected']
# Processed MAR 1598 rows: [500712.0, 'SJNHS-II', 'Moyot St.', '60403000', 1178, 1178, 0, 0, 'Unknown']
# Processed APR 1598 rows: [500712.0, 'SJNHS-II', 'Moyot St.', '60403000', 1178, 1178, 0, 0, 'Unknown']
# Processed MAR 1599 rows: [500134.0, 'Sola, Manuel', 'Moyot St.', nan, 2234, 2260, 26, 260, 'Connected']
# Processed APR 1599 rows: [500134.0, 'Sola, Manuel', 'Moyot St.', nan, 2260, 2286, 26, 260, 'Connected']
# Processed MAR 1600 rows: [501610.0, 'Sola, Daniel', 'Moyot St.', nan, 340, 382, 42, 420, 'Connected']
# Processed APR 1600 rows: [501610.0, 'Sola, Daniel', 'Moyot St.', nan, 382, 423, 41, 410, 'Connected']
# Processed MAR 1601 rows: [501607.0, 'Villamor, Analyn', 'Moyot St.', nan, 405, 435, 30, 300, 'Connected']
# Processed APR 1601 rows: [501607.0, 'Villamor, Analyn', 'Moyot St.', nan, 435, 465, 30, 300, 'Connected']
# Processed MAR 1602 rows: [501213.0, 'Verano, Eduardo', 'Moyot St.', '017994-02', 523, 535, 12, 120, 'Connected']
# Processed APR 1602 rows: [501213.0, 'Verano, Eduardo', 'Moyot St.', '017994-02', 535, 548, 13, 130, 'Connected']
# Processed MAR 1603 rows: [500227.0, 'Young, Marleen', 'Moyot St.', '098012-02', 2571, 2571, 0, 0, 'Connected']
# Processed APR 1603 rows: [500227.0, 'Young, Marleen', 'Moyot St.', '098012-02', 2571, 2571, 0, 0, 'Connected']
# Processed MAR 1604 rows: [501113.0, 'Alcantara, Isabel', 'Villamor St.', nan, 351, 372, 21, 210, 'Connected']
# Processed APR 1604 rows: [501113.0, 'Alcantara, Isabel', 'Villamor St.', nan, 372, 393, 21, 210, 'Connected']
# Processed MAR 1605 rows: [501334.0, 'Alcantara, Galahad', 'Villamor St.', nan, 855, 880, 25, 250, 'Connected']
# Processed APR 1605 rows: [501334.0, 'Alcantara, Galahad', 'Villamor St.', nan, 880, 905, 25, 250, 'Connected']
# Processed MAR 1606 rows: [500020.0, 'Alicante, Anacleto', 'Villamor St.', '27971', 855, 855, 0, 0, 'Unknown']
# Processed APR 1606 rows: [500020.0, 'Alicante, Anacleto', 'Villamor St.', '27971', 855, 855, 0, 0, 'Unknown']
# Processed MAR 1607 rows: [500346.0, 'Almodiel, Jason', 'Villamor St.', '028668-02', 2951, 2999, 48, 480, 'Connected']
# Processed APR 1607 rows: [500346.0, 'Almodiel, Jason', 'Villamor St.', '028668-02', 2999, 3046, 47, 470, 'Connected']
# Processed MAR 1608 rows: [500895.0, 'Almoete, Felipe Jr.', 'Villamor St.', '1118055', 2083, 2097, 14, 140, 'Connected']
# Processed APR 1608 rows: [500895.0, 'Almoete, Felipe Jr.', 'Villamor St.', '1118055', 2097, 2110, 13, 130, 'Connected']
# Processed MAR 1609 rows: [500226.0, 'Almoete, Ligaya', 'Villamor St.', '95761', 2194, 2200, 6, 60, 'Connected']
# Processed APR 1609 rows: [500226.0, 'Almoete, Ligaya', 'Villamor St.', '95761', 2200, 2206, 6, 60, 'Connected']
# Processed MAR 1610 rows: [500885.0, 'Añonuevo, Florante', 'Villamor St.', nan, 2194, 2194, 0, 0, 'Unknown']
# Processed APR 1610 rows: [500885.0, 'Añonuevo, Florante', 'Villamor St.', nan, 2194, 2194, 0, 0, 'Unknown']
# Processed MAR 1611 rows: [500640.0, 'Añonuevo, Lilibeth', 'Villamor St.', '9867182', 2458, 2466, 8, 80, 'Connected']
# Processed APR 1611 rows: [500640.0, 'Añonuevo, Lilibeth', 'Villamor St.', '9867182', 2466, 2474, 8, 80, 'Connected']
# Processed MAR 1612 rows: [501186.0, 'Balingasa, Adril (1)', 'Villamor St.', '10114216', 447, 487, 40, 400, 'Connected']
# Processed APR 1612 rows: [501186.0, 'Balingasa, Adril (1)', 'Villamor St.', '10114216', 487, 528, 41, 410, 'Connected']
# Processed MAR 1613 rows: [501215.0, 'Balingasa, Ma. Elena (3)', 'Villamor St.', '901847', 162, 182, 20, 200, 'Connected']
# Processed APR 1613 rows: [501215.0, 'Balingasa, Ma. Elena (3)', 'Villamor St.', '901847', 182, 203, 21, 210, 'Connected']
# Processed MAR 1614 rows: [501228.0, 'Balingasa, Joadel (2)', 'Villamor St.', '10114293', 676, 676, 0, 0, 'Connected']
# Processed APR 1614 rows: [501228.0, 'Balingasa, Joadel (2)', 'Villamor St.', '10114293', 676, 676, 0, 0, 'Connected']
# Processed MAR 1615 rows: [501217.0, 'Balingasa, Jea (4)', 'Villamor St.', '10113695', 453, 475, 22, 220, 'Connected']
# Processed APR 1615 rows: [501217.0, 'Balingasa, Jea (4)', 'Villamor St.', '10113695', 475, 497, 22, 220, 'Connected']
# Processed MAR 1616 rows: [501257.0, 'Barrun, Ma. Jossette', 'Villamor St.', nan, 2721, 2761, 40, 400, 'Connected']
# Processed APR 1616 rows: [501257.0, 'Barrun, Ma. Jossette', 'Villamor St.', nan, 2761, 2802, 41, 410, 'Connected']
# Processed MAR 1617 rows: [500090.0, 'Barrun, Emma', 'Villamor St.', '957419', 1782, 1816, 34, 340, 'Connected']
# Processed APR 1617 rows: [500090.0, 'Barrun, Emma', 'Villamor St.', '957419', 1816, 1851, 35, 350, 'Connected']
# Processed MAR 1618 rows: [501634.0, 'Benamera, Sharon Mae', 'Villamor St.', nan, 548, 657, 109, 1090, 'Connected']
# Processed APR 1618 rows: [501634.0, 'Benamera, Sharon Mae', 'Villamor St.', nan, 657, 766, 109, 1090, 'Connected']
# Processed MAR 1619 rows: [501523.0, 'Diano, Alvin', 'Villamor St.', nan, 522, 568, 46, 460, 'Connected']
# Processed APR 1619 rows: [501523.0, 'Diano, Alvin', 'Villamor St.', nan, 568, 614, 46, 460, 'Connected']
# Processed MAR 1620 rows: [500642.0, 'Escorel, Elisa', 'Villamor St.', nan, 3522, 3548, 26, 260, 'Connected']
# Processed APR 1620 rows: [500642.0, 'Escorel, Elisa', 'Villamor St.', nan, 3548, 3574, 26, 260, 'Connected']
# Processed MAR 1621 rows: [501112.0, 'Espiloy, Nemia', 'Villamor St.', '151912', 251, 297, 46, 460, 'Connected']
# Processed APR 1621 rows: [501112.0, 'Espiloy, Nemia', 'Villamor St.', '151912', 297, 344, 47, 470, 'Connected']
# Processed MAR 1622 rows: [500092.0, 'Bartolata, Eduardo', 'Villamor St.', '967426', 251, 251, 0, 0, 'Unknown']
# Processed APR 1622 rows: [500092.0, 'Bartolata, Eduardo', 'Villamor St.', '967426', 251, 251, 0, 0, 'Unknown']
# Processed MAR 1623 rows: [501012.0, 'Garibalde, Alcantara', 'Villamor St.', nan, 251, 251, 0, 0, 'Unknown']
# Processed APR 1623 rows: [501012.0, 'Garibalde, Alcantara', 'Villamor St.', nan, 251, 251, 0, 0, 'Unknown']
# Processed MAR 1624 rows: [500919.0, 'Granado, Nida', 'Villamor St.', '10758', 251, 251, 0, 0, 'Unknown']
# Processed APR 1624 rows: [500919.0, 'Granado, Nida', 'Villamor St.', '10758', 251, 251, 0, 0, 'Unknown']
# Processed MAR 1625 rows: [501110.0, 'Gutierrez, Elmo', 'Villamor St.', '2624', 10, 10, 0, 0, 'Connected']
# Processed APR 1625 rows: [501110.0, 'Gutierrez, Elmo', 'Villamor St.', '2624', 10, 10, 0, 0, 'Connected']
# Processed MAR 1626 rows: [501662.0, 'Latagan, Mercy', 'Villamor St.', nan, 10, 26, 16, 160, 'Connected']
# Processed APR 1626 rows: [501662.0, 'Latagan, Mercy', 'Villamor St.', nan, 26, 43, 17, 170, 'Connected']
# Processed MAR 1627 rows: [501111.0, 'Laurio, Serenida', 'Villamor St.', '017890-02', 1339, 1390, 51, 510, 'Connected']
# Processed APR 1627 rows: [501111.0, 'Laurio, Serenida', 'Villamor St.', '017890-02', 1390, 1441, 51, 510, 'Connected']
# Processed MAR 1628 rows: [500641.0, 'Moya, Conception', 'Villamor St.', '017921-02', 1339, 1339, 0, 0, 'Unknown']
# Processed APR 1628 rows: [500641.0, 'Moya, Conception', 'Villamor St.', '017921-02', 1339, 1339, 0, 0, 'Unknown']
# Processed MAR 1629 rows: [500021.0, 'Nacino, Christopher', 'Villamor St.', '9511454', 1784, 1786, 2, 20, 'Connected']
# Processed APR 1629 rows: [500021.0, 'Nacino, Christopher', 'Villamor St.', '9511454', 1786, 1787, 1, 10, 'Connected']
# Processed MAR 1630 rows: [500091.0, 'Ragasa, Fe', 'Villamor St.', '017732-02', 2894, 2916, 22, 220, 'Connected']
# Processed APR 1630 rows: [500091.0, 'Ragasa, Fe', 'Villamor St.', '017732-02', 2916, 2938, 22, 220, 'Connected']
# Processed MAR 1631 rows: [501109.0, 'Almocera, Ricky', 'Puro, Calipat-an', '18010', 2894, 2894, 0, 0, 'Disconnected']
# Processed APR 1631 rows: [501109.0, 'Almocera, Ricky', 'Puro, Calipat-an', '18010', 2894, 2894, 0, 0, 'Disconnected']
# Processed MAR 1632 rows: [501381.0, 'Gaurano, Clutario', 'Puro, Calipat-an', nan, 2894, 2894, 0, 0, 'Disconnected']
# Processed APR 1632 rows: [501381.0, 'Gaurano, Clutario', 'Puro, Calipat-an', nan, 2894, 2894, 0, 0, 'Disconnected']
# Processing complete!

# %%
# Read the data with optimized dtypes
dtypes = {
    'Control Number': 'str',
    "Consumer's Name": 'str',
    'Address': 'str',
    'Water Meter Serial #': 'str',
    'Previous': 'float64',
    'Present': 'float64',
    'Current': 'float64',
    'Cons.': 'float64',
    'Amount': 'float64'
}

# Read the CSV
new_df = pd.read_csv("../../dataset/raw/2020/APR2020.csv", 
                    encoding='latin-1',
                    dtype=dtypes)

# Check for negative consumption
print("=== Negative Consumption Summary ===")
neg_consumption = new_df[new_df['Cons.'] < 0]
print(f"Total rows with negative consumption: {len(neg_consumption)}")
if not neg_consumption.empty:
    print("\nSample of rows with negative consumption:")
    print(neg_consumption[['Control Number', 'Previous', 'Present', 'Cons.']].head())

# Check for negative amount
print("\n=== Negative Amount Summary ===")
neg_amount = new_df[new_df['Amount'] < 0]
print(f"Total rows with negative amount: {len(neg_amount)}")
if not neg_amount.empty:
    print("\nSample of rows with negative amount:")
    print(neg_amount[['Control Number', 'Cons.', 'Amount']].head())

# Additional checks
print("\n=== Additional Data Quality Checks ===")
print(f"Total rows: {len(new_df)}")
print(f"Rows with zero consumption: {len(new_df[new_df['Cons.'] == 0])}")
print(f"Rows with missing values: {new_df.isnull().any(axis=1).sum()}")
# Out:
# === Negative Consumption Summary ===
# Total rows with negative consumption: 1
#
# Sample of rows with negative consumption:
#     Control Number  Previous  Present  Cons.
# 171       500741.0      58.0     14.0  -44.0
#
# === Negative Amount Summary ===
# Total rows with negative amount: 1
#
# Sample of rows with negative amount:
#     Control Number  Cons.  Amount
# 171       500741.0  -44.0  -440.0
#
# === Additional Data Quality Checks ===
# Total rows: 1633
# Rows with zero consumption: 544
# Rows with missing values: 698

# %% [markdown]
# # Create records for AUG2022 and SEP2022

# %%
# Review of consumption difference
july_df = pd.read_csv("../../dataset/raw/2022/JUL2022.csv", encoding='latin-1')
oct_df = pd.read_csv("../../dataset/raw/2022/OCT2022.csv", encoding='latin-1')
nov_df = pd.read_csv("../../dataset/raw/2022/NOV2022.csv", encoding='latin-1')
dec_df = pd.read_csv("../../dataset/raw/2022/DEC2022.csv", encoding='latin-1')

july_df['Present'] = pd.to_numeric(july_df['Present'], errors='coerce')
oct_df['Present'] = pd.to_numeric(oct_df['Present'], errors='coerce')
nov_df['Present'] = pd.to_numeric(nov_df['Present'], errors='coerce')
dec_df['Present'] = pd.to_numeric(dec_df['Present'], errors='coerce')

july_mini_df = july_df[['Control Number', 'Consumer\'s Name', 'Previous', 'Present']]
oct_mini_df = oct_df[['Control Number', 'Consumer\'s Name', 'Previous', 'Present']]
nov_mini_df = nov_df[['Control Number', 'Consumer\'s Name', 'Previous', 'Present']]
dec_mini_df = dec_df[['Control Number', 'Consumer\'s Name', 'Previous', 'Present']] 

merged_df = pd.merge(july_mini_df, oct_mini_df, on=['Control Number', 'Consumer\'s Name'], suffixes=('_july', '_oct'))
merged_df = pd.merge(merged_df, nov_mini_df, on=['Control Number', 'Consumer\'s Name'], suffixes=('_oct', '_nov'))
merged_df = pd.merge(merged_df, dec_mini_df, on=['Control Number', 'Consumer\'s Name'], suffixes=('_nov', '_dec'))

merged_df['Consumption Difference'] = pd.to_numeric(merged_df['Present_oct']) - pd.to_numeric(merged_df['Present_july'])

negative_df = merged_df[merged_df['Consumption Difference'] < 0]
print("Negative Consumption Difference Count: ", len(negative_df))
display(negative_df.head())
display(negative_df)
# Out:
# Negative Consumption Difference Count:  14
#      Control Number  Consumer's Name Previous_july  Present_july Previous_oct  \
# 802          500606   Almoete, Oscar          2571        2571.0         2548
# 882          500375        Mira, Noe          3514        3514.0         3512
# 930          500682  Almosara, Celin          3009        3024.0          NaN
# 963          501355   Bocboc, Evelyn          1000        1030.0          NaN
# 964          500881     Bocboc, Lily          1456        1478.0          NaN
#
#      Present_oct Previous_nov  Present_nov Previous_dec  Present_dec  \
# 802       2555.0         2555       2601.0         2349       2374.0
# 882       3512.0         3512       3514.0         3512       3512.0
# 930         43.0           43          NaN         2881       2903.0
# 963          6.0            6         18.0          966        968.0
# 964         74.0           74          NaN       DEFECT          NaN
#
#      Consumption Difference
# 802                   -16.0
# 882                    -2.0
# 930                 -2981.0
# 963                 -1024.0
# 964                 -1404.0
#       Control Number     Consumer's Name Previous_july  Present_july  \
# 802           500606      Almoete, Oscar          2571        2571.0
# 882           500375           Mira, Noe          3514        3514.0
# 930           500682     Almosara, Celin          3009        3024.0
# 963           501355      Bocboc, Evelyn          1000        1030.0
# 964           500881        Bocboc, Lily          1456        1478.0
# 978           501592  Dejino, Evangeline          1818        1881.0
# 1021          501158      Gupalao, Roger           609         622.0
# 1046          501688  Pinaranda, Maricel           347         350.0
# 1072          500066     Almodal, Glenda          4755        4755.0
# 1221          500960     Almojuela, Nila           973         973.0
# 1403          501087     Lignes, Marissa          4823        4823.0
# 1405          500917           Lim, Nena          1234        1234.0
# 1450          500426       Rivera, Erwin          4360        4360.0
# 1763          501358      Pontalba, Joel          5735        5735.0
#
#      Previous_oct  Present_oct Previous_nov  Present_nov Previous_dec  \
# 802          2548       2555.0         2555       2601.0         2349
# 882          3512       3512.0         3512       3514.0         3512
# 930           NaN         43.0           43          NaN         2881
# 963           NaN          6.0            6         18.0          966
# 964           NaN         74.0           74          NaN       DEFECT
# 978           NaN         55.0           55         72.0       DEFECT
# 1021          NaN          8.0            8         40.0          494
# 1046          NaN         31.0           31         59.0          256
# 1072           19         22.0           22         25.0         4743
# 1221           26         35.0           35         48.0       DEFECT
# 1403           32         70.0           70        120.0         4480
# 1405           38         87.0           87        165.0         1234
# 1450         4303       4304.0         4304       4305.0         4036
# 1763       DEFECT       3735.0         5735       5735.0         5685
#
#       Present_dec  Consumption Difference
# 802        2374.0                   -16.0
# 882        3512.0                    -2.0
# 930        2903.0                 -2981.0
# 963         968.0                 -1024.0
# 964           NaN                 -1404.0
# 978           NaN                 -1826.0
# 1021        509.0                  -614.0
# 1046        271.0                  -319.0
# 1072       4755.0                 -4733.0
# 1221        973.0                  -938.0
# 1403       4526.0                 -4753.0
# 1405       1234.0                 -1147.0
# 1450       4036.0                   -56.0
# 1763       5685.0                 -2000.0

# %%
print(f'Null Present Readings Count: {july_mini_df['Present'].isnull().sum()}')
print(f'Null Previous Readings Count: {july_mini_df['Previous'].isnull().sum()}')

# Coerce to numeric and create masks for invalid entries
present_numeric = pd.to_numeric(july_mini_df["Present"], errors="coerce")
previous_numeric = pd.to_numeric(july_mini_df["Previous"], errors="coerce")

# Boolean masks where coercion failed (i.e., non-numeric values)
invalid_present_mask = present_numeric.isna() & july_mini_df["Present"].notna()
invalid_previous_mask = previous_numeric.isna() & july_mini_df["Previous"].notna()

# Extract invalid entries
invalid_present_values = july_mini_df.loc[invalid_present_mask, "Present"].unique()
invalid_previous_values = july_mini_df.loc[invalid_previous_mask, "Previous"].unique()

# Report results
print(f"Non-Numeric Present Readings Count: {invalid_present_mask.sum()}")
print(f"Values: {invalid_present_values.tolist()}")

print(f"Non-Numeric Previous Readings Count: {invalid_previous_mask.sum()}")
print(f"Values: {invalid_previous_values.tolist()}")
# Out:
# Null Present Readings Count: 539
# Null Previous Readings Count: 58
# Non-Numeric Present Readings Count: 0
# Values: []
# Non-Numeric Previous Readings Count: 478
# Values: ['DISC.', 'DEFECT', 'TECH. DEFECT', 'TEMP. DISC.']

# %%
# Null row check for Present and Previous columns of july_mini_df
july_null_rows = july_mini_df[july_mini_df[['Present', 'Previous']].isnull().any(axis=1)]
print('Null row count: ', len(july_null_rows))
display(july_null_rows)

# Remove null rows from oct_mini_df
oct_null_rows = oct_mini_df[oct_mini_df[['Present', 'Previous']].isnull().any(axis=1)]
print('Null row count: ', len(oct_null_rows))
display(oct_null_rows)
# Out:
# Null row count:  542
#       Control Number       Consumer's Name Previous  Present
# 5             501542        Almiñe, Filben    DISC.      NaN
# 6             500431      Almiñe, Franchie    DISC.      NaN
# 10            500739        Almodal, Jolly   DEFECT      NaN
# 13            501447  Almodiel, Mary Grace   DEFECT      NaN
# 21            500260      Altiche, Antonio   DEFECT      NaN
# ...              ...                   ...      ...      ...
# 1918          501112        Espiloy, Nemia    DISC.      NaN
# 1919          500919         Granado, Nida    DISC.      NaN
# 1924          500641      Moya, Concepcion    DISC.      NaN
# 1927          501109       Almocera, Ricky    DISC.      NaN
# 1928          501381     Gaurano, Clutario    DISC.      NaN
#
# [542 rows x 4 columns]
# Null row count:  619
#       Control Number    Consumer's Name Previous  Present
# 4             501704  Almiñana, Violeta      184      NaN
# 6             501542     Almiñe, Filben    DISC.      NaN
# 7             500431   Almiñe, Franchie    DISC.      NaN
# 10            500484     Almodal, Judem     1147      NaN
# 11            500739     Almodal, Jolly   DEFECT      NaN
# ...              ...                ...      ...      ...
# 1969          501112     Espiloy, Nemia    DISC.      NaN
# 1970          500919      Granado, Nida    DISC.      NaN
# 1975          500641   Moya, Concepcion    DISC.      NaN
# 1978          501109    Almocera, Ricky    DISC.      NaN
# 1979          501381  Gaurano, Clutario    DISC.      NaN
#
# [619 rows x 4 columns]

# %%
import re 

jul_input_df = pd.read_csv("../../dataset/raw/2022/JUL2022.csv", encoding='latin-1')
oct_input_df = pd.read_csv("../../dataset/raw/2022/OCT2022.csv", encoding='latin-1')

jul_str_list = []
oct_str_list = []

def check_instance(x, month):
    if isinstance(x, str) and re.search(r"[a-zA-Z]", x):
        if month == 'JUL':
            jul_str_list.append(x)
        elif month == 'OCT':
            oct_str_list.append(x)
    else:   
        pass

jul_input_df["Present"].apply(lambda x: check_instance(x, 'JUL'))
oct_input_df["Present"].apply(lambda x: check_instance(x, 'OCT'))

jul_input_df["Previous"].apply(lambda x: check_instance(x, 'JUL'))
oct_input_df["Previous"].apply(lambda x: check_instance(x, 'OCT'))

print(set(jul_str_list))
print(set(oct_str_list))
print(set(jul_str_list).union(set(oct_str_list)))
# Out:
# {'DEFECT', 'TEMP. DISC.', 'DISC.', 'TECH. DEFECT'}
# {'DEFECT', 'DISC.', 'TEMP. DISC.', 'TEMP. CLOSED'}
# {'DEFECT', 'DISC.', 'TEMP. DISC.', 'TEMP. CLOSED', 'TECH. DEFECT'}

# %%
# DATASET PREPARATION
# Step 1: Read the input CSVs
jul_input_df = pd.read_csv("../../dataset/raw/2022/JUL2022.csv", encoding='latin-1')
oct_input_df = pd.read_csv("../../dataset/raw/2022/OCT2022.csv", encoding='latin-1')

# Step 2: Define the function to clean Present/Previous readings
def fill_reading(row, primary, secondary):
    if pd.isna(row[primary]) and pd.notna(row[secondary]):
        return row[secondary]
    elif pd.isna(row[primary]) and pd.isna(row[secondary]):
        return 0
    else:
        return row[primary]

def analyze_connection(row, primary, secondary):
    invalid_values = {'DEFECT': 'Defect', 'DISC.': 'Disconnected', 'TEMP. DISC.': 'Temporarily Disconnected', 'TEMP. CLOSED': 'Temporarily Closed', 'TECH. DEFECT': 'Technical Defect', '0': 'Invalid'}
    if pd.isna(row[primary]) and pd.notna(row[secondary]):
        if row[secondary] in invalid_values:
            return invalid_values[row[secondary]]
        elif pd.notna(row[f'Cleaned {primary}']):
            return "Resolved"
        else:
            return "Invalid"
    elif pd.notna(row[primary]) and pd.isna(row[secondary]):
        if pd.notna(row[f'Cleaned {primary}']):
            return "Resolved"
        else:
            return "Invalid"
    elif pd.isna(row[primary]) and pd.isna(row[secondary]):
        return "Invalid"
    else:
        return "Valid"

# Step 3: Apply row-wise filling
jul_input_df["Cleaned Present"] = jul_input_df.apply(lambda row: fill_reading(row, "Present", "Previous"), axis=1)
jul_input_df["Cleaned Previous"] = jul_input_df.apply(lambda row: fill_reading(row, "Previous", "Present"), axis=1)

oct_input_df["Cleaned Present"] = oct_input_df.apply(lambda row: fill_reading(row, "Present", "Previous"), axis=1)
oct_input_df["Cleaned Previous"] = oct_input_df.apply(lambda row: fill_reading(row, "Previous", "Present"), axis=1)

# Step 4: Add status columns
jul_input_df["Status"] = jul_input_df.apply(lambda row: analyze_connection(row, "Present", "Previous"), axis=1)
oct_input_df["Status"] = oct_input_df.apply(lambda row: analyze_connection(row, "Present", "Previous"), axis=1)

# Step 5: Display the cleaned columns
display(jul_input_df[["Present", "Previous", "Cleaned Present", "Cleaned Previous", "Status"]].head())
display(oct_input_df[["Present", "Previous", "Cleaned Present", "Cleaned Previous", "Status"]].head())
# Out:
#   Present Previous Cleaned Present Cleaned Previous Status
# 0     544      544             544              544  Valid
# 1    3274     3274            3274             3274  Valid
# 2    1401     1401            1401             1401  Valid
# 3     147      147             147              147  Valid
# 4     894      894             894              894  Valid
#   Present Previous Cleaned Present Cleaned Previous    Status
# 0     610      585             610              585     Valid
# 1     321      315             321              315     Valid
# 2    3359     3327            3359             3327     Valid
# 3    1631     1581            1631             1581     Valid
# 4     NaN      184             184              184  Resolved

# %%
# Count Check
print("JUL2022 shape:", jul_input_df.shape)
print("OCT2022 shape:", oct_input_df.shape)

# Step 1: Check for duplicate records
print("Duplicate records in JUL2022:", jul_input_df.duplicated().sum())
print("Duplicate records in OCT2022:", oct_input_df.duplicated().sum())

merged_ref_df = pd.merge(
    jul_input_df,
    oct_input_df,
    on=["Control Number", "Consumer's Name", "Address", "Water Meter Serial #"],
    how="inner",
    suffixes=('_JUL', '_OCT')
)

# Final display with Status included
display(merged_ref_df.head())
# Out:
# JUL2022 shape: (1929, 11)
# OCT2022 shape: (1980, 11)
# Duplicate records in JUL2022: 0
# Duplicate records in OCT2022: 0
#    Control Number      Consumer's Name       Address Water Meter Serial #  \
# 0          501549       Albaño, Lilane  Alicante St.                  NaN
# 1          500750  Aljecera, Marcelino  Alicante St.                  NaN
# 2          500990       Almiñana, Irus  Alicante St.                  NaN
# 3          501704    Almiñana, Violeta  Alicante St.                  NaN
# 4          500505       Almiñe, Edison  Alicante St.             95022096
#
#   Previous_JUL Present_JUL  Cons._JUL Amount_JUL Cleaned Present_JUL  \
# 0          544         544        NaN     60.00                  544
# 1         3274        3274        NaN     60.00                 3274
# 2         1401        1401        NaN     60.00                 1401
# 3          147         147        NaN        NaN                 147
# 4          894         894        NaN     60.00                  894
#
#   Cleaned Previous_JUL Status_JUL Previous_OCT Present_OCT  Cons._OCT  \
# 0                  544      Valid          585         610       25.0
# 1                 3274      Valid         3327        3359       32.0
# 2                 1401      Valid         1581        1631       50.0
# 3                  147      Valid          184         NaN        NaN
# 4                  894      Valid          983        1023       40.0
#
#   Amount_OCT Cleaned Present_OCT Cleaned Previous_OCT Status_OCT
# 0        150                 610                  585      Valid
# 1        192                3359                 3327      Valid
# 2        300                1631                 1581      Valid
# 3        NaN                 184                  184   Resolved
# 4        240                1023                  983      Valid

# %%
# Final Check
print("Final shape:", merged_ref_df.shape)
print("Duplicate records:", merged_ref_df.duplicated().sum())
display(merged_ref_df["Status_JUL"].value_counts())
display(merged_ref_df["Status_OCT"].value_counts())
# Out:
# Final shape: (1879, 18)
# Duplicate records: 0
# Status_JUL
# Valid       1815
# Invalid       52
# Resolved      12
# Name: count, dtype: int64
# Status_OCT
# Valid           1779
# Resolved          42
# Invalid           39
# Disconnected      19
# Name: count, dtype: int64

# %%
display(merged_ref_df[merged_ref_df["Status_JUL"] == "Invalid"])
# Out:
#       Control Number          Consumer's Name          Address  \
# 74            500985          Escorel, Potito     Alicante St.
# 90            500623         Grencio, Maribel     Alicante St.
# 104           500559           Laurio, Josefa     Alicante St.
# 128           501878             Ramiro, Geny     Alicante St.
# 143           500381                     UCCP     Alicante St.
# 202           500070       Bartolay, Victor 2    Altarejos St.
# 238           500704         Sola, Andres Jr.    Altarejos St.
# 247           501899            Almoete, Joey       Amican St.
# 299           500509     Ticao Dist. Hospital       Amican St.
# 340           501382   Balingasa, Maria Elena       Bailon St.
# 405           501864       Kho Shipping Lines       Bailon St.
# 429           501819       Menes, Natividad 2       Bailon St.
# 486           501914          Bartolata, Romy     Balcavem St.
# 488           501907           Bartolay, Lory     Balcavem St.
# 672           501017                Liao, Liz   Bartolabac St.
# 719           501236        Espinosa, Manette     Bartolay St.
# 750           501858         Espinosa, Arlene  Binaliw, Burgos
# 794           500600  Heirs of Estor, Domingo     Don Juan St.
# 829           501892            Ancheta, Rona    Esparrago St.
# 836           500321              Barrun, May    Esparrago St.
# 860           500001       Encinares, Roberto    Esparrago St.
# 883           501903          Lignes, Maricel    Esparrago St.
# 885           501902          Lignes, Neulita    Esparrago St.
# 888           501808           Lozano, Pepito    Esparrago St.
# 911           501327      Villamor, Guillermo    Esparrago St.
# 919           501397     Barruga, Maria Luisa     Espinosa St.
# 922           500292            Elloso, Ramir     Espinosa St.
# 941           501921        Almencion, Evalyn       Fabmar St.
# 1004          501911          Dejucos, Shielo       Fabmar St.
# 1036          501916         Garamay, Marites       Fabmar St.
# 1094          501886        Almodal, Glenda 2       Flores St.
# 1168          501908                 SJCS (1)       Flores St.
# 1169          501909                 SJCS (2)       Flores St.
# 1412          500410             Laila, Dante        Jones St.
# 1440          501162          Marques, Nelson        Jones St.
# 1450          501630         Mores, Hera Myra        Jones St.
# 1504          501923           Almodal, Glenn       Letada St.
# 1528          500477        Constantino, Aida       Letada St.
# 1553          501922   Ongonion, Mark Anthony       Letada St.
# 1560          501906        San Juan, Marissa       Letada St.
# 1583          500722          Albacite, Helen        Lique St.
# 1695          501917              Belen, Nena        Moyot St.
# 1722          501470          Delavin, Nonito        Moyot St.
# 1809          501904         Escorel, Jezebel       NHA Duplex
# 1819          501848      Arcenas, John Chris   Talaba, Burgos
# 1825          501918       Delavin, Carlo (1)   Talaba, Burgos
#
#      Cleaned Present_JUL Cleaned Previous_JUL Status_JUL Previous_OCT  \
# 74                     0                    0    Invalid          NaN
# 90                     0                    0    Invalid          782
# 104                    0                    0    Invalid          NaN
# 128                    0                    0    Invalid           42
# 143                    0                    0    Invalid         7388
# 202                    0                    0    Invalid         2952
# 238                    0                    0    Invalid       DEFECT
# 247                    0                    0    Invalid           16
# 299                    0                    0    Invalid          NaN
# 340                    0                    0    Invalid          NaN
# 405                    0                    0    Invalid          138
# 429                    0                    0    Invalid          NaN
# 486                    0                    0    Invalid           28
# 488                    0                    0    Invalid          128
# 672                    0                    0    Invalid          NaN
# 719                    0                    0    Invalid          NaN
# 750                    0                    0    Invalid          NaN
# 794                    0                    0    Invalid          331
# 829                    0                    0    Invalid           12
# 836                    0                    0    Invalid         5615
# 860                    0                    0    Invalid        DISC.
# 883                    0                    0    Invalid          NaN
# 885                    0                    0    Invalid          NaN
# 888                    0                    0    Invalid          NaN
# 911                    0                    0    Invalid        DISC.
# 919                    0                    0    Invalid          NaN
# 922                    0                    0    Invalid          NaN
# 941                    0                    0    Invalid          104
# 1004                   0                    0    Invalid           97
# 1036                   0                    0    Invalid          NaN
# 1094                   0                    0    Invalid          NaN
# 1168                   0                    0    Invalid          130
# 1169                   0                    0    Invalid          NaN
# 1412                   0                    0    Invalid          NaN
# 1440                   0                    0    Invalid          164
# 1450                   0                    0    Invalid          730
# 1504                   0                    0    Invalid           19
# 1528                   0                    0    Invalid          233
# 1553                   0                    0    Invalid           40
# 1560                   0                    0    Invalid           50
# 1583                   0                    0    Invalid          NaN
# 1695                   0                    0    Invalid           92
# 1722                   0                    0    Invalid        DISC.
# 1809                   0                    0    Invalid           34
# 1819                   0                    0    Invalid          NaN
# 1825                   0                    0    Invalid          193
# 1826                   0                    0    Invalid           15
# 1827                   0                    0    Invalid          127
# 1828                   0                    0    Invalid           65
# 1839                   0                    0    Invalid           17
# 1840                   0                    0    Invalid            6
# 1844                   0                    0    Invalid          NaN
#
#      Present_OCT  Cons._OCT Amount_OCT Cleaned Present_OCT  \
# 74           NaN        NaN        NaN                   0
# 90           819       37.0        222                 819
# 104          NaN        NaN        NaN                   0
# 128           54       12.0         72                  54
# 143         7393        5.0         60                7393
# 202         2952        NaN         60                2952
# 238          791        NaN         60                 791
# 247           16        NaN         60                  16
# 299          NaN        NaN        900                   0
# 340          NaN        NaN        NaN                   0
# 405          138        NaN         60                 138
# 429          NaN        NaN        NaN                   0
# 486           36        8.0         60                  36
# 488          153       25.0        150                 153
# 672          NaN        NaN        NaN                   0
# 719          NaN        NaN        NaN                   0
# 750          NaN        NaN        NaN                   0
# 794          331        NaN         60                 331
# 829           25       13.0         78                  25
# 836         5632       17.0        102                5632
# 860        DISC.        NaN        NaN               DISC.
# 883          NaN        NaN        NaN                   0
# 885          NaN        NaN        NaN                   0
# 888          NaN        NaN        NaN                   0
# 911        DISC.        NaN        NaN               DISC.
# 919          NaN        NaN        NaN                   0
# 922          NaN        NaN         60                   0
# 941          148       44.0        264                 148
# 1004         136       39.0        234                 136
# 1036         NaN        NaN        NaN                   0
# 1094         NaN        NaN        NaN                   0
# 1168         251      121.0        726                 251
# 1169         NaN        NaN        NaN                   0
# 1412         NaN        NaN        NaN                   0
# 1440         181       17.0        102                 181
# 1450         730        NaN         60                 730
# 1504          22        3.0         60                  22
# 1528         251       18.0        108                 251
# 1553          54       14.0         84                  54
# 1560          64       14.0         84                  64
# 1583         NaN        NaN        NaN                   0
# 1695         130       38.0        228                 130
# 1722       DISC.        NaN         60               DISC.
# 1809          45       11.0         66                  45
# 1819         NaN        NaN        NaN                   0
# 1825         203       10.0         60                 203
# 1826          16        1.0         60                  16
# 1827         157       30.0        180                 157
# 1828         110       45.0        270                 110
# 1839          25        8.0         60                  25
# 1840           8        2.0         60                   8
# 1844         NaN        NaN        NaN                   0
#
#      Cleaned Previous_OCT Status_OCT
# 74                      0    Invalid
# 90                    782      Valid
# 104                     0    Invalid
# 128                    42      Valid
# 143                  7388      Valid
# 202                  2952      Valid
# 238                DEFECT      Valid
# 247                    16      Valid
# 299                     0    Invalid
# 340                     0    Invalid
# 405                   138      Valid
# 429                     0    Invalid
# 486                    28      Valid
# 488                   128      Valid
# 672                     0    Invalid
# 719                     0    Invalid
# 750                     0    Invalid
# 794                   331      Valid
# 829                    12      Valid
# 836                  5615      Valid
# 860                 DISC.      Valid
# 883                     0    Invalid
# 885                     0    Invalid
# 888                     0    Invalid
# 911                 DISC.      Valid
# 919                     0    Invalid
# 922                     0    Invalid
# 941                   104      Valid
# 1004                   97      Valid
# 1036                    0    Invalid
# 1094                    0    Invalid
# 1168                  130      Valid
# 1169                    0    Invalid
# 1412                    0    Invalid
# 1440                  164      Valid
# 1450                  730      Valid
# 1504                   19      Valid
# 1528                  233      Valid
# 1553                   40      Valid
# 1560                   50      Valid
# 1583                    0    Invalid
# 1695                   92      Valid
# 1722                DISC.      Valid
# 1809                   34      Valid
# 1819                    0    Invalid
# 1825                  193      Valid
# 1826                   15      Valid
# 1827                  127      Valid
# 1828                   65      Valid
# 1839                   17      Valid
# 1840                    6      Valid
# 1844                    0    Invalid

# %%
# SEP2022 Records Creation 
import os
import csv
import pandas as pd

# Mount the reference billings
jul_input_df = pd.read_csv("../../dataset/raw/2022/JUL2022.csv", encoding='latin-1')
oct_input_df = pd.read_csv("../../dataset/raw/2022/OCT2022.csv", encoding='latin-1')

# Merge the reference billings
merged_ref_df = pd.merge(jul_input_df, oct_input_df, on=["Control Number", "Consumer\'s Name", "Address"], how="inner")

# Create the output directory if it doesn't exist
sep_output_dir = os.path.dirname("../../dataset/raw/2022/SEP2022.csv")
oct_output_dir = os.path.dirname("../../dataset/raw/2022/OCT2022.csv")
os.makedirs(sep_output_dir, exist_ok=True)
os.makedirs(oct_output_dir, exist_ok=True)

with open("../../dataset/raw/2022/SEP2022.csv", "w", newline="", encoding='latin-1') as sep_file \
    , open("../../dataset/raw/2022/OCT2022.csv", "w", newline="", encoding='latin-1') as oct_file:
